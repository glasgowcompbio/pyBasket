# %% [markdown]
# # GDSCv2 Analysis - Erlotinib (10 clusters)
#
# This notebook shows a PyMC model that incorporates basket + clustering

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

sys.path.append('..')
sys.path.append('.')

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import seaborn as sns
from sklearn.cluster import KMeans

# %%
from pyBasket.common import load_obj, save_obj
from pyBasket.model import get_patient_model_simple, get_patient_model_hierarchical
from pyBasket.model import get_patient_model_hierarchical_log_odds, get_patient_model_hierarchical_log_odds_nc
from pyBasket.clustering import get_cluster_df_by_basket, plot_PCA, get_patient_df
from pyBasket.preprocessing import select_rf, check_rf

# %% [markdown]
# # Load expression data

# %%
data_dir = os.path.abspath(os.path.join('..', 'Data'))
data_dir
# Out:
# '/Users/joewandy/Work/git/pyBasket/Data'

# %% [markdown]
# The data consists of 446 samples x 19957 transcripts

# %%
expr_file = os.path.join(data_dir, 'GDSCv2.exprsALL.tsv')
df = pd.read_csv(expr_file, sep='\t')
expr_df = df.drop(df.index[-25:]).transpose()
expr_df
# Out:
#            ENSG00000000003.15  ENSG00000000005.6  ENSG00000000419.12  \
# TGBC24TKB            3.842223          -5.465508            6.643472
# EGI-1                5.477477          -3.712215            5.685061
# TGBC1TKB             5.247886          -5.464387            6.443945
# ETK-1                5.772839          -5.669225            6.345230
# SW1710               3.891433          -6.720904            6.461246
# ...                       ...                ...                 ...
# ASH-3                3.230687          -9.965784            6.793055
# KMH-2                2.644470          -9.965784            7.369643
# HTC-C3               4.297403          -9.965784            6.790183
# IHH-4                2.770616          -5.795143            5.490973
# HEC-1                4.511196          -4.535588            6.296627
#
#            ENSG00000000457.14  ENSG00000000460.17  ENSG00000000938.13  \
# TGBC24TKB            2.413681            3.523928           -6.722421
# EGI-1                3.274900            3.243179           -4.146015
# TGBC1TKB             2.174270            4.884496           -3.860326
# ETK-1                2.088130            4.272358           -6.904595
# SW1710               2.432792            3.541814           -6.584625
# ...                       ...                 ...                 ...
# ASH-3                2.174138            2.815748           -6.168741
# KMH-2                2.521319            4.211213           -9.965784
# HTC-C3               1.780538            2.229505           -2.115773
# IHH-4                3.801877            4.603189           -2.927377
# HEC-1                2.463557            4.079280           -6.010182
#
#            ENSG00000000971.16  ENSG00000001036.14  ENSG00000001084.13  \
# TGBC24TKB            1.493328            5.312851            7.657224
# EGI-1                4.508079            4.801951            4.677299
# TGBC1TKB            -2.119720            6.585122            7.530231
# ETK-1                2.426256            6.914759            6.597911
# SW1710               4.976817            5.593969            4.455942
# ...                       ...                 ...                 ...
# ASH-3                3.105009            4.966726            4.675848
# KMH-2                1.926462            5.212597            3.104173
# HTC-C3               3.557124            4.339450            4.492282
# IHH-4               -3.172772           -0.264386            4.179838
# HEC-1                0.860272            5.429501            5.651821
#
#            ENSG00000001167.14  ...  ENSG00000288436.1  ENSG00000288460.1  \
# TGBC24TKB            4.241038  ...          -9.965784          -6.590911
# EGI-1                4.812610  ...          -5.393783          -6.552767
# TGBC1TKB             4.834777  ...          -3.459260          -9.965784
# ETK-1                4.163071  ...          -3.497535          -6.780472
# SW1710               5.065822  ...          -2.528606          -5.514698
# ...                       ...  ...                ...                ...
# ASH-3                4.668331  ...          -9.965784          -9.965784
# KMH-2                3.763338  ...          -6.705062          -9.965784
# HTC-C3               4.175475  ...          -9.965784          -6.805531
# IHH-4                4.530007  ...          -2.538738          -5.954484
# HEC-1                3.993226  ...          -3.963675          -6.868090
#
#            ENSG00000288520.1  ENSG00000288529.1  ENSG00000288534.1  \
# TGBC24TKB          -9.965784          -9.965784           3.498175
# EGI-1              -4.030988          -9.965784           2.821231
# TGBC1TKB           -6.932179          -9.965784           2.675651
# ETK-1              -3.047387          -9.965784           3.500665
# SW1710             -4.137394          -9.965784           3.020995
# ...                      ...                ...                ...
# ASH-3              -9.965784          -9.965784           1.998570
# KMH-2              -1.975997          -9.965784           2.052412
# HTC-C3             -9.965784          -9.965784           1.023656
# IHH-4              -9.965784          -9.965784           1.825162
# HEC-1              -4.969760          -9.965784           2.647948
#
#            ENSG00000288547.1  ENSG00000288550.1  ENSG00000288558.1  \
# TGBC24TKB          -9.965784          -0.647309           1.826165
# EGI-1              -9.965784          -1.324475           1.050212
# TGBC1TKB           -3.173723          -2.442109           1.872312
# ETK-1              -9.965784          -1.753472           1.533735
# SW1710             -1.689065          -1.219231           1.743528
# ...                      ...                ...                ...
# ASH-3              -9.965784          -0.486651           0.090239
# KMH-2              -9.965784          -0.561202          -0.021777
# HTC-C3             -9.965784          -1.808425           0.997827
# IHH-4              -9.965784          -2.307655           1.466204
# HEC-1              -9.965784          -1.311239           1.580561
#
#            ENSG00000288564.1  ENSG00000288570.1
# TGBC24TKB          -5.399761          -9.965784
# EGI-1              -3.380326          -9.965784
# TGBC1TKB           -2.986262          -9.965784
# ETK-1              -3.042083          -9.965784
# SW1710             -1.304345          -9.965784
# ...                      ...                ...
# ASH-3              -1.683468          -9.965784
# KMH-2              -2.262192          -9.965784
# HTC-C3             -2.137166          -9.965784
# IHH-4              -2.971226          -9.965784
# HEC-1              -4.063903          -9.965784
#
# [446 rows x 19957 columns]

# %% [markdown]
# Each sample is assigned to one tissue

# %%
tissue_df = df.tail(25).astype(int).transpose()
tissue_df
# Out:
#            CNS/Brain  Bone  Prostate  Esophagus/Stomach  \
# TGBC24TKB          0     0         0                  0
# EGI-1              0     0         0                  0
# TGBC1TKB           0     0         0                  0
# ETK-1              0     0         0                  0
# SW1710             0     0         0                  0
# ...              ...   ...       ...                ...
# ASH-3              0     0         0                  0
# KMH-2              0     0         0                  0
# HTC-C3             0     0         0                  0
# IHH-4              0     0         0                  0
# HEC-1              0     0         0                  0
#
#            Bladder/Urinary Tract  Ovary/Fallopian Tube  Lymphoid  Kidney  \
# TGBC24TKB                      0                     0         0       0
# EGI-1                          0                     0         0       0
# TGBC1TKB                       0                     0         0       0
# ETK-1                          0                     0         0       0
# SW1710                         1                     0         0       0
# ...                          ...                   ...       ...     ...
# ASH-3                          0                     0         0       0
# KMH-2                          0                     0         0       0
# HTC-C3                         0                     0         0       0
# IHH-4                          0                     0         0       0
# HEC-1                          0                     0         0       0
#
#            Thyroid  Soft Tissue  ...  Uterus  Pancreas  Breast  Cervix  Bowel  \
# TGBC24TKB        0            0  ...       0         0       0       0      0
# EGI-1            0            0  ...       0         0       0       0      0
# TGBC1TKB         0            0  ...       0         0       0       0      0
# ETK-1            0            0  ...       0         0       0       0      0
# SW1710           0            0  ...       0         0       0       0      0
# ...            ...          ...  ...     ...       ...     ...     ...    ...
# ASH-3            1            0  ...       0         0       0       0      0
# KMH-2            1            0  ...       0         0       0       0      0
# HTC-C3           1            0  ...       0         0       0       0      0
# IHH-4            1            0  ...       0         0       0       0      0
# HEC-1            0            0  ...       1         0       0       0      0
#
#            Peripheral Nervous System  Liver  Biliary Tract  Other  \
# TGBC24TKB                          0      0              1      0
# EGI-1                              0      0              1      0
# TGBC1TKB                           0      0              1      0
# ETK-1                              0      0              1      0
# SW1710                             0      0              0      0
# ...                              ...    ...            ...    ...
# ASH-3                              0      0              0      0
# KMH-2                              0      0              0      0
# HTC-C3                             0      0              0      0
# IHH-4                              0      0              0      0
# HEC-1                              0      0              0      0
#
#            Ampulla of Vater
# TGBC24TKB                 0
# EGI-1                     0
# TGBC1TKB                  0
# ETK-1                     0
# SW1710                    0
# ...                     ...
# ASH-3                     0
# KMH-2                     0
# HTC-C3                    0
# IHH-4                     0
# HEC-1                     0
#
# [446 rows x 25 columns]

# %%
flat_list = tissue_df.reset_index().melt(id_vars='index', var_name='tissue', value_name='belongs_to_tissue')
flat_list = flat_list[flat_list['belongs_to_tissue'] != 0]

# set the index to the sample name
flat_list = flat_list.set_index('index')

# create the dictionary
sample_dict = flat_list['tissue'].to_dict()

# %%
tissues = np.array([sample_dict[s] for s in expr_df.index.values])
tissues[0:10]
# Out:
# array(['Biliary Tract', 'Biliary Tract', 'Biliary Tract', 'Biliary Tract',
#        'Bladder/Urinary Tract', 'Bladder/Urinary Tract',
#        'Bladder/Urinary Tract', 'Bladder/Urinary Tract',
#        'Bladder/Urinary Tract', 'Bone'], dtype='<U25')

# %% [markdown]
# # Do PCA and colour by basket (tissues)

# %%
_ = plot_PCA(expr_df, n_components=10, hue=tissues)
# Out:
# PCA explained variance [0.12949628 0.22238095 0.28729125 0.32075101 0.34293046 0.36347672
#  0.38132787 0.39535599 0.40877655 0.4209827 ]

# %% [markdown]
# # Load drug responses data

# %% [markdown]
# Each sample also has its corresponding drug response. There are 11 drugs.

# %%
response_file = os.path.join(data_dir, 'GDSCv2.aacALL.tsv')
response_df = pd.read_csv(response_file, sep='\t').transpose()
response_df
# Out:
#           Bortezomib  Entinostat  Sirolimus  Docetaxel  Gemcitabine  \
# 143B             NaN         NaN        NaN        NaN          NaN
# 201T             NaN         NaN        NaN        NaN          NaN
# 22Rv1       0.184836    0.142503   0.304184   0.111977     0.596289
# 23132/87    0.228235    0.121580   0.208475   0.232821     0.407328
# 380              NaN         NaN        NaN        NaN          NaN
# ...              ...         ...        ...        ...          ...
# YH-13       0.174638    0.019992   0.157624   0.211467     0.359880
# YKG-1            NaN         NaN        NaN        NaN          NaN
# YMB-1-E          NaN         NaN        NaN        NaN          NaN
# YT          0.230123         NaN   0.212004   0.113564     0.666782
# ZR-75-30    0.029824    0.036509   0.110687   0.061314     0.141155
#
#           Crizotinib  Lapatinib  Vorinostat  Erlotinib  Paclitaxel  Pictilisib
# 143B             NaN        NaN         NaN        NaN         NaN         NaN
# 201T             NaN        NaN         NaN        NaN         NaN         NaN
# 22Rv1       0.077036   0.048663    0.240865   0.069736    0.015539    0.254125
# 23132/87    0.018921   0.172438    0.235145   0.124366    0.025982    0.431203
# 380              NaN        NaN         NaN        NaN         NaN         NaN
# ...              ...        ...         ...        ...         ...         ...
# YH-13       0.008977   0.069979    0.144077   0.108331    0.087400    0.349741
# YKG-1            NaN        NaN         NaN        NaN         NaN         NaN
# YMB-1-E          NaN        NaN         NaN        NaN         NaN         NaN
# YT               NaN   0.084477    0.235547   0.000000    0.000000    0.172903
# ZR-75-30    0.000000   0.402298    0.066816   0.059044    0.000000    0.150910
#
# [1104 rows x 11 columns]

# %%
response_df.loc['TGBC24TKB']
# Out:
# Bortezomib     0.046804
# Entinostat     0.074151
# Sirolimus      0.015096
# Docetaxel      0.229496
# Gemcitabine    0.410541
# Crizotinib     0.000000
# Lapatinib      0.239909
# Vorinostat     0.181613
# Erlotinib      0.128392
# Paclitaxel     0.014104
# Pictilisib     0.387379
# Name: TGBC24TKB, dtype: float64

# %% [markdown]
# ## Collect the samples and responses for the drug

# %%
drug_name = 'Erlotinib'

# %%
samples = tissue_df.index.values
response_dict = response_df[drug_name].to_dict()
responses = np.array([response_dict[s] for s in samples])
len(samples), len(responses), len(tissues)
# Out:
# (446, 446, 446)

# %%
df = pd.DataFrame({
    'tissues': tissues,
    'samples': samples,    
    'responses': responses
})
df
# Out:
#                    tissues    samples  responses
# 0            Biliary Tract  TGBC24TKB   0.128392
# 1            Biliary Tract      EGI-1   0.057719
# 2            Biliary Tract   TGBC1TKB   0.051036
# 3            Biliary Tract      ETK-1   0.096227
# 4    Bladder/Urinary Tract     SW1710   0.071891
# ..                     ...        ...        ...
# 441                Thyroid      ASH-3   0.082204
# 442                Thyroid      KMH-2        NaN
# 443                Thyroid     HTC-C3   0.078680
# 444                Thyroid      IHH-4   0.020141
# 445                 Uterus      HEC-1   0.087076
#
# [446 rows x 3 columns]

# %% [markdown]
# ## Drop all the NaN responses

# %%
df = df.dropna(subset=['responses'])
df
# Out:
#                    tissues    samples  responses
# 0            Biliary Tract  TGBC24TKB   0.128392
# 1            Biliary Tract      EGI-1   0.057719
# 2            Biliary Tract   TGBC1TKB   0.051036
# 3            Biliary Tract      ETK-1   0.096227
# 4    Bladder/Urinary Tract     SW1710   0.071891
# ..                     ...        ...        ...
# 440                Thyroid        WRO   0.018343
# 441                Thyroid      ASH-3   0.082204
# 443                Thyroid     HTC-C3   0.078680
# 444                Thyroid      IHH-4   0.020141
# 445                 Uterus      HEC-1   0.087076
#
# [298 rows x 3 columns]

# %%
df['tissues'].unique()
# Out:
# array(['Biliary Tract', 'Bladder/Urinary Tract', 'Bone', 'Bowel',
#        'Breast', 'Cervix', 'CNS/Brain', 'Esophagus/Stomach',
#        'Head and Neck', 'Kidney', 'Liver', 'Lung', 'Lymphoid', 'Myeloid',
#        'Other', 'Ovary/Fallopian Tube', 'Pancreas',
#        'Peripheral Nervous System', 'Pleura', 'Prostate', 'Skin',
#        'Soft Tissue', 'Thyroid', 'Uterus'], dtype=object)

# %%
df.groupby('tissues').count()
# Out:
#                            samples  responses
# tissues
# Biliary Tract                    4          4
# Bladder/Urinary Tract            5          5
# Bone                            25         25
# Bowel                           28         28
# Breast                          10         10
# CNS/Brain                       14         14
# Cervix                          13         13
# Esophagus/Stomach               19         19
# Head and Neck                   16         16
# Kidney                           5          5
# Liver                            2          2
# Lung                            24         24
# Lymphoid                        53         53
# Myeloid                         12         12
# Other                            3          3
# Ovary/Fallopian Tube            10         10
# Pancreas                         5          5
# Peripheral Nervous System       15         15
# Pleura                          10         10
# Prostate                         2          2
# Skin                             8          8
# Soft Tissue                      7          7
# Thyroid                          7          7
# Uterus                           1          1

# %%
df['responses'].max(), df['responses'].min()
# Out:
# (0.352487709036072, 0.0)

# %%
sns.displot(df['responses'])

# %%
df['responses'].mean(), df['responses'].median()
# Out:
# (0.07533823628570624, 0.06098308922444)

# %% [markdown]
# # Select baskets for analysis

# %% [markdown]
# Select some baskets

# %%
# basket_names = [
#     'Lymphoid',
#     'Bowel',
#     'Bone',
#     'Lung',
#     'Esophagus/Stomach'
# ]

# %% [markdown]
# Use all baskets

# %%
basket_names = df['tissues'].unique()
basket_names
# Out:
# array(['Biliary Tract', 'Bladder/Urinary Tract', 'Bone', 'Bowel',
#        'Breast', 'Cervix', 'CNS/Brain', 'Esophagus/Stomach',
#        'Head and Neck', 'Kidney', 'Liver', 'Lung', 'Lymphoid', 'Myeloid',
#        'Other', 'Ovary/Fallopian Tube', 'Pancreas',
#        'Peripheral Nervous System', 'Pleura', 'Prostate', 'Skin',
#        'Soft Tissue', 'Thyroid', 'Uterus'], dtype=object)

# %%
df_filtered = df[df['tissues'].isin(basket_names)].reset_index(drop=True)
df_filtered
# Out:
#                    tissues    samples  responses
# 0            Biliary Tract  TGBC24TKB   0.128392
# 1            Biliary Tract      EGI-1   0.057719
# 2            Biliary Tract   TGBC1TKB   0.051036
# 3            Biliary Tract      ETK-1   0.096227
# 4    Bladder/Urinary Tract     SW1710   0.071891
# ..                     ...        ...        ...
# 293                Thyroid        WRO   0.018343
# 294                Thyroid      ASH-3   0.082204
# 295                Thyroid     HTC-C3   0.078680
# 296                Thyroid      IHH-4   0.020141
# 297                 Uterus      HEC-1   0.087076
#
# [298 rows x 3 columns]

# %%
sample_list = df_filtered['samples'].tolist()
expr_df_filtered = expr_df[expr_df.index.isin(sample_list)]
expr_df_filtered.shape, expr_df.shape
# Out:
# ((298, 19957), (446, 19957))

# %%
expr_df_filtered
# Out:
#            ENSG00000000003.15  ENSG00000000005.6  ENSG00000000419.12  \
# TGBC24TKB            3.842223          -5.465508            6.643472
# EGI-1                5.477477          -3.712215            5.685061
# TGBC1TKB             5.247886          -5.464387            6.443945
# ETK-1                5.772839          -5.669225            6.345230
# SW1710               3.891433          -6.720904            6.461246
# ...                       ...                ...                 ...
# WRO                  3.205753          -9.965784            7.307272
# ASH-3                3.230687          -9.965784            6.793055
# HTC-C3               4.297403          -9.965784            6.790183
# IHH-4                2.770616          -5.795143            5.490973
# HEC-1                4.511196          -4.535588            6.296627
#
#            ENSG00000000457.14  ENSG00000000460.17  ENSG00000000938.13  \
# TGBC24TKB            2.413681            3.523928           -6.722421
# EGI-1                3.274900            3.243179           -4.146015
# TGBC1TKB             2.174270            4.884496           -3.860326
# ETK-1                2.088130            4.272358           -6.904595
# SW1710               2.432792            3.541814           -6.584625
# ...                       ...                 ...                 ...
# WRO                 -0.607968            0.481533           -9.965784
# ASH-3                2.174138            2.815748           -6.168741
# HTC-C3               1.780538            2.229505           -2.115773
# IHH-4                3.801877            4.603189           -2.927377
# HEC-1                2.463557            4.079280           -6.010182
#
#            ENSG00000000971.16  ENSG00000001036.14  ENSG00000001084.13  \
# TGBC24TKB            1.493328            5.312851            7.657224
# EGI-1                4.508079            4.801951            4.677299
# TGBC1TKB            -2.119720            6.585122            7.530231
# ETK-1                2.426256            6.914759            6.597911
# SW1710               4.976817            5.593969            4.455942
# ...                       ...                 ...                 ...
# WRO                  0.725387            5.847553            4.118905
# ASH-3                3.105009            4.966726            4.675848
# HTC-C3               3.557124            4.339450            4.492282
# IHH-4               -3.172772           -0.264386            4.179838
# HEC-1                0.860272            5.429501            5.651821
#
#            ENSG00000001167.14  ...  ENSG00000288436.1  ENSG00000288460.1  \
# TGBC24TKB            4.241038  ...          -9.965784          -6.590911
# EGI-1                4.812610  ...          -5.393783          -6.552767
# TGBC1TKB             4.834777  ...          -3.459260          -9.965784
# ETK-1                4.163071  ...          -3.497535          -6.780472
# SW1710               5.065822  ...          -2.528606          -5.514698
# ...                       ...  ...                ...                ...
# WRO                  4.821918  ...          -6.475129          -6.749269
# ASH-3                4.668331  ...          -9.965784          -9.965784
# HTC-C3               4.175475  ...          -9.965784          -6.805531
# IHH-4                4.530007  ...          -2.538738          -5.954484
# HEC-1                3.993226  ...          -3.963675          -6.868090
#
#            ENSG00000288520.1  ENSG00000288529.1  ENSG00000288534.1  \
# TGBC24TKB          -9.965784          -9.965784           3.498175
# EGI-1              -4.030988          -9.965784           2.821231
# TGBC1TKB           -6.932179          -9.965784           2.675651
# ETK-1              -3.047387          -9.965784           3.500665
# SW1710             -4.137394          -9.965784           3.020995
# ...                      ...                ...                ...
# WRO                -9.965784          -9.965784           2.933364
# ASH-3              -9.965784          -9.965784           1.998570
# HTC-C3             -9.965784          -9.965784           1.023656
# IHH-4              -9.965784          -9.965784           1.825162
# HEC-1              -4.969760          -9.965784           2.647948
#
#            ENSG00000288547.1  ENSG00000288550.1  ENSG00000288558.1  \
# TGBC24TKB          -9.965784          -0.647309           1.826165
# EGI-1              -9.965784          -1.324475           1.050212
# TGBC1TKB           -3.173723          -2.442109           1.872312
# ETK-1              -9.965784          -1.753472           1.533735
# SW1710             -1.689065          -1.219231           1.743528
# ...                      ...                ...                ...
# WRO                -9.965784          -2.224737          -1.366209
# ASH-3              -9.965784          -0.486651           0.090239
# HTC-C3             -9.965784          -1.808425           0.997827
# IHH-4              -9.965784          -2.307655           1.466204
# HEC-1              -9.965784          -1.311239           1.580561
#
#            ENSG00000288564.1  ENSG00000288570.1
# TGBC24TKB          -5.399761          -9.965784
# EGI-1              -3.380326          -9.965784
# TGBC1TKB           -2.986262          -9.965784
# ETK-1              -3.042083          -9.965784
# SW1710             -1.304345          -9.965784
# ...                      ...                ...
# WRO                -1.616199          -9.965784
# ASH-3              -1.683468          -9.965784
# HTC-C3             -2.137166          -9.965784
# IHH-4              -2.971226          -9.965784
# HEC-1              -4.063903          -9.965784
#
# [298 rows x 19957 columns]

# %%
drug_response = df_filtered.set_index('samples').drop(columns=['tissues'])
drug_response
# Out:
#            responses
# samples
# TGBC24TKB   0.128392
# EGI-1       0.057719
# TGBC1TKB    0.051036
# ETK-1       0.096227
# SW1710      0.071891
# ...              ...
# WRO         0.018343
# ASH-3       0.082204
# HTC-C3      0.078680
# IHH-4       0.020141
# HEC-1       0.087076
#
# [298 rows x 1 columns]

# %% [markdown]
# ## Feature selection using random forest

# %%
try: # try to load previously selected features
    fname = os.path.join('results', '%s_expr_df_selected.p' % drug_name)
    expr_df_selected = load_obj(fname)
    
except FileNotFoundError: # if not found, then re-run feature selection
    expr_df_selected = select_rf(expr_df_filtered, drug_response, n_splits=5, percentile_threshold=90, top_genes=500)
    save_obj(expr_df_selected, fname)

# %%
importance_df = check_rf(expr_df_selected, drug_response, test_size=0.2)
# Out:
# Test set results using selected features:
# MSE: 0.0032920842730129398
# R^2: 0.20947838405718378

# %%
expr_df_selected
# Out:
#            ENSG00000090621.14  ENSG00000132517.15  ENSG00000146648.18  \
# TGBC24TKB            6.381521           -1.739429            3.321716
# EGI-1                7.610135           -0.751374            5.163625
# TGBC1TKB             6.751622           -1.513449            5.945249
# ETK-1                7.070839            0.127958            5.787218
# SW1710               7.775491           -2.199953            5.858155
# ...                       ...                 ...                 ...
# WRO                  7.837784           -1.353844            3.763408
# ASH-3                7.723500           -2.473594            5.331743
# HTC-C3               6.924446           -0.875604            5.030717
# IHH-4                6.970922           -1.798209            5.552850
# HEC-1                7.510966           -1.265750            4.673156
#
#            ENSG00000149043.16  ENSG00000152894.14  ENSG00000163347.6  \
# TGBC24TKB           -0.004531            4.734547           5.931521
# EGI-1                1.493216            4.720908           6.417578
# TGBC1TKB             0.627148            5.272171           4.621619
# ETK-1               -0.107128            6.046211           5.308687
# SW1710              -2.758373            5.425618           4.544722
# ...                       ...                 ...                ...
# WRO                 -6.732831            5.742105           4.760012
# ASH-3               -6.200127            4.661784           1.397889
# HTC-C3              -4.996494            6.072599           9.227226
# IHH-4               -5.065087            3.918782           3.639364
# HEC-1               -8.440116            4.697114           7.674048
#
#            ENSG00000168143.9  ENSG00000180638.17  ENSG00000198888.2  \
# TGBC24TKB           3.111430            1.966194          13.627491
# EGI-1               3.203289           -1.841590          13.199545
# TGBC1TKB            2.635736           -1.039889          12.951333
# ETK-1               2.477480           -1.037587          12.310494
# SW1710             -4.269562           -0.381611          12.271514
# ...                      ...                 ...                ...
# WRO                -2.607410           -2.643596          10.482648
# ASH-3              -3.950847           -3.144996          12.233519
# HTC-C3              0.302072           -2.257324          12.757065
# IHH-4              -3.606497           -2.172558          13.085928
# HEC-1              -4.000182            0.873241          13.262868
#
#            ENSG00000205420.11  ...  ENSG00000116752.6  ENSG00000116791.14  \
# TGBC24TKB            2.205512  ...           5.162435            5.147299
# EGI-1               -1.218443  ...           4.925232            5.226792
# TGBC1TKB             7.054224  ...           6.148827            5.062208
# ETK-1                0.961998  ...           5.247601            4.840509
# SW1710              -6.245291  ...           5.025107            7.285653
# ...                       ...  ...                ...                 ...
# WRO                 -5.459191  ...           5.281934            5.111793
# ASH-3               -5.668614  ...           5.997219            5.313866
# HTC-C3              -3.826678  ...           5.712599            5.132686
# IHH-4               -9.965784  ...           4.845341            4.250295
# HEC-1               -9.965784  ...           5.057443            7.231520
#
#            ENSG00000116906.13  ENSG00000117280.13  ENSG00000117385.16  \
# TGBC24TKB            5.606865            2.998651            2.689027
# EGI-1                5.603523            2.670388            3.690611
# TGBC1TKB             5.476686            3.565310            2.989053
# ETK-1                6.286441            3.783611            4.020878
# SW1710               5.875248            4.852093            6.105435
# ...                       ...                 ...                 ...
# WRO                  4.432248            2.312542            5.967269
# ASH-3                4.264601            3.448109            6.406388
# HTC-C3               5.115367            4.164872            4.130017
# IHH-4                5.615404            4.699264            4.436642
# HEC-1                5.255280            5.628483            5.721549
#
#            ENSG00000117560.8  ENSG00000118096.8  ENSG00000118292.9  \
# TGBC24TKB          -4.084599           1.582791          -2.710111
# EGI-1              -3.501878           3.994157           2.254687
# TGBC1TKB           -3.608304           2.541695          -0.928687
# ETK-1              -4.522908           3.410838           0.532800
# SW1710             -4.621762           3.015028           0.782099
# ...                      ...                ...                ...
# WRO                -4.153537           2.695865           0.825085
# ASH-3              -4.216887           4.299667           1.986339
# HTC-C3             -4.510880           5.400644           0.639323
# IHH-4              -4.521843           3.689322           1.936225
# HEC-1              -4.366459           4.038209           1.532701
#
#            ENSG00000118705.17  ENSG00000118785.14
# TGBC24TKB            7.812905            5.147392
# EGI-1                7.025284           -4.545513
# TGBC1TKB             7.818634            4.432519
# ETK-1                8.133642            9.654010
# SW1710               7.713363            9.941758
# ...                       ...                 ...
# WRO                  6.924745            4.096984
# ASH-3                7.446398            1.274876
# HTC-C3               7.529029            1.770304
# IHH-4                6.832362            0.901152
# HEC-1                8.227425            9.301020
#
# [298 rows x 500 columns]

# %% [markdown]
# ## Do PCA again on these samples

# %% [markdown]
# Before feature selection (using all 19957 transcripts)

# %%
pc1, pc2 = plot_PCA(expr_df_filtered, n_components=10, hue=df_filtered['tissues'].values)
# Out:
# PCA explained variance [0.13829637 0.22985784 0.29027512 0.32311007 0.34617996 0.36607902
#  0.38141876 0.39592535 0.4093223  0.42133611]

# %%
plt.figure(figsize=(10, 5))
g = sns.scatterplot(x=pc1, y=pc2, hue=df_filtered['responses'].values, palette='Blues')
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1, fontsize=12)

# %% [markdown]
# After feature selection (using 500 transcripts)

# %%
pc1, pc2 = plot_PCA(expr_df_selected, n_components=10, hue=df_filtered['tissues'].values)
# Out:
# PCA explained variance [0.2443426  0.31842748 0.37138039 0.41483141 0.43467953 0.45420608
#  0.47068115 0.48621428 0.5008843  0.51525205]

# %%
plt.figure(figsize=(10, 5))
g = sns.scatterplot(x=pc1, y=pc2, hue=df_filtered['responses'].values, palette='Blues')
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1, fontsize=12)

# %% [markdown]
# # Try clustering

# %%
expr_df_selected.shape
# Out:
# (298, 500)

# %%
classes = df_filtered.set_index('samples')
classes
# Out:
#                          tissues  responses
# samples
# TGBC24TKB          Biliary Tract   0.128392
# EGI-1              Biliary Tract   0.057719
# TGBC1TKB           Biliary Tract   0.051036
# ETK-1              Biliary Tract   0.096227
# SW1710     Bladder/Urinary Tract   0.071891
# ...                          ...        ...
# WRO                      Thyroid   0.018343
# ASH-3                    Thyroid   0.082204
# HTC-C3                   Thyroid   0.078680
# IHH-4                    Thyroid   0.020141
# HEC-1                     Uterus   0.087076
#
# [298 rows x 2 columns]

# %%
C = 10

# %%
kmeans = KMeans(n_clusters=C, random_state=42)
kmeans.fit(expr_df_selected)

cluster_labels = kmeans.labels_
cluster_labels
# Out:
# array([4, 4, 0, 4, 2, 0, 2, 0, 0, 1, 6, 6, 2, 6, 6, 6, 6, 6, 2, 6, 6, 1,
#        1, 6, 1, 2, 6, 1, 6, 6, 2, 6, 6, 2, 4, 7, 4, 7, 4, 4, 4, 4, 0, 4,
#        4, 4, 4, 4, 1, 4, 4, 4, 2, 9, 4, 4, 4, 4, 4, 4, 4, 4, 7, 7, 7, 7,
#        7, 7, 7, 7, 0, 7, 4, 0, 0, 0, 9, 0, 2, 7, 0, 0, 7, 1, 0, 2, 1, 2,
#        6, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 4, 4, 0, 0, 7, 4, 4, 0, 4, 4,
#        4, 0, 0, 4, 0, 1, 4, 4, 0, 2, 0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 1, 0,
#        0, 2, 2, 2, 2, 2, 2, 1, 1, 1, 5, 0, 5, 4, 9, 4, 9, 9, 9, 1, 9, 4,
#        0, 9, 4, 1, 9, 9, 9, 7, 5, 9, 9, 8, 8, 8, 3, 8, 3, 3, 3, 3, 8, 8,
#        8, 3, 8, 3, 8, 8, 8, 8, 8, 8, 3, 8, 3, 8, 3, 8, 3, 3, 8, 3, 8, 8,
#        3, 3, 3, 8, 3, 3, 3, 8, 8, 8, 8, 3, 3, 3, 1, 8, 3, 3, 3, 3, 8, 3,
#        8, 8, 8, 8, 3, 8, 8, 3, 8, 8, 2, 4, 3, 4, 4, 2, 2, 4, 2, 1, 4, 2,
#        0, 7, 2, 4, 2, 0, 5, 5, 5, 5, 5, 5, 5, 5, 1, 5, 5, 5, 1, 5, 5, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 7, 2, 1, 1, 1, 1, 1, 1, 1, 2, 2, 2,
#        5, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2], dtype=int32)

# %%
_ = plot_PCA(expr_df_selected, n_components=10, hue=cluster_labels)
# Out:
# PCA explained variance [0.2443426  0.31842748 0.37138039 0.41483141 0.43467953 0.45420608
#  0.47068115 0.48621428 0.5008843  0.51525205]

# %% [markdown]
# # Run basket trial analysis

# %%
basket_names
# Out:
# array(['Biliary Tract', 'Bladder/Urinary Tract', 'Bone', 'Bowel',
#        'Breast', 'Cervix', 'CNS/Brain', 'Esophagus/Stomach',
#        'Head and Neck', 'Kidney', 'Liver', 'Lung', 'Lymphoid', 'Myeloid',
#        'Other', 'Ovary/Fallopian Tube', 'Pancreas',
#        'Peripheral Nervous System', 'Pleura', 'Prostate', 'Skin',
#        'Soft Tissue', 'Thyroid', 'Uterus'], dtype=object)

# %%
K = len(basket_names)
K, C
# Out:
# (24, 10)

# %% [markdown]
# Create clustering dataframe

# %%
class_labels = classes.tissues.values
len(class_labels), len(cluster_labels)
# Out:
# (298, 298)

# %%
cluster_df = get_cluster_df_by_basket(class_labels, cluster_labels, normalise=False)
cluster_df
# Out:
#                            sk_0  sk_1  sk_2  sk_3  sk_4  sk_5  sk_6  sk_7  \
# Biliary Tract                 1     0     0     0     3     0     0     0
# Bladder/Urinary Tract         3     0     2     0     0     0     0     0
# Bone                          0     5     5     0     0     0    15     0
# Bowel                         1     1     1     0    22     0     0     2
# Breast                        1     0     0     0     0     0     0     9
# CNS/Brain                     0     2    11     0     0     0     1     0
# Cervix                        7     1     1     0     1     0     0     2
# Esophagus/Stomach             6     2     0     0    10     0     0     1
# Head and Neck                12     1     3     0     0     0     0     0
# Kidney                        0     0     5     0     0     0     0     0
# Liver                         0     2     0     0     0     0     0     0
# Lung                          2     3     0     0     4     3     0     1
# Lymphoid                      0     1     0    26     0     0     0     0
# Myeloid                       0     0     0     3     0     0     0     0
# Other                         0     0     1     1     1     0     0     0
# Ovary/Fallopian Tube          1     1     4     0     4     0     0     0
# Pancreas                      1     0     2     0     1     0     0     1
# Peripheral Nervous System     0     2     0     0     0    13     0     0
# Pleura                        0     0    10     0     0     0     0     0
# Prostate                      1     0     0     0     0     0     0     1
# Skin                          0     7     1     0     0     0     0     0
# Soft Tissue                   0     0     6     0     0     1     0     0
# Thyroid                       0     0     6     0     1     0     0     0
# Uterus                        0     0     1     0     0     0     0     0
#
#                            sk_8  sk_9
# Biliary Tract                 0     0
# Bladder/Urinary Tract         0     0
# Bone                          0     0
# Bowel                         0     1
# Breast                        0     0
# CNS/Brain                     0     0
# Cervix                        0     1
# Esophagus/Stomach             0     0
# Head and Neck                 0     0
# Kidney                        0     0
# Liver                         0     0
# Lung                          0    11
# Lymphoid                     26     0
# Myeloid                       9     0
# Other                         0     0
# Ovary/Fallopian Tube          0     0
# Pancreas                      0     0
# Peripheral Nervous System     0     0
# Pleura                        0     0
# Prostate                      0     0
# Skin                          0     0
# Soft Tissue                   0     0
# Thyroid                       0     0
# Uterus                        0     0

# %%
sns.heatmap(cluster_df, cmap='jet')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Prepare patient data

# %%
patient_df = get_patient_df(df_filtered, cluster_labels)

# %%
patient_df
# Out:
#                          tissues  responses  basket_number  cluster_number  \
# samples
# TGBC24TKB          Biliary Tract   0.128392              0               4
# EGI-1              Biliary Tract   0.057719              0               4
# TGBC1TKB           Biliary Tract   0.051036              0               0
# ETK-1              Biliary Tract   0.096227              0               4
# SW1710     Bladder/Urinary Tract   0.071891              1               2
# ...                          ...        ...            ...             ...
# WRO                      Thyroid   0.018343             22               2
# ASH-3                    Thyroid   0.082204             22               2
# HTC-C3                   Thyroid   0.078680             22               4
# IHH-4                    Thyroid   0.020141             22               2
# HEC-1                     Uterus   0.087076             23               2
#
#            responsive
# samples
# TGBC24TKB           0
# EGI-1               1
# TGBC1TKB            1
# ETK-1               0
# SW1710              0
# ...               ...
# WRO                 1
# ASH-3               0
# HTC-C3              0
# IHH-4               1
# HEC-1               0
#
# [298 rows x 5 columns]

# %% [markdown]
# ## Define models

# %% [markdown]
# No. of samples to collect before and after burn-in during MCMC.

# %%
n_burn_in = int(5E3)
n_sample = int(5E3)
target_accept = 0.99

# %% [markdown]
# ### Simple model

# %%
model_s = get_patient_model_simple(patient_df)

# %%
pm.model_to_graphviz(model_s)

# %%
with model_s:
    trace_s = pm.sample(n_sample, tune=n_burn_in, idata_kwargs={'log_likelihood': True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [basket_p, cluster_p]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 01:08&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 5_000 tune and 5_000 draw iterations (20_000 + 20_000 draws total) took 96 seconds.

# %%
az.summary(trace_s).round(2)
# Out:
#                                  mean    sd  hdi_3%  hdi_97%  mcse_mean  \
# basket_p[Biliary Tract]          0.67  0.22    0.29     1.00        0.0
# basket_p[Bladder/Urinary Tract]  0.70  0.19    0.37     1.00        0.0
# basket_p[Bone]                   0.74  0.15    0.50     1.00        0.0
# basket_p[Bowel]                  0.69  0.18    0.41     1.00        0.0
# basket_p[Breast]                 0.62  0.20    0.30     1.00        0.0
# ...                               ...   ...     ...      ...        ...
# cluster_p[Uterus, 7]             0.50  0.29    0.03     0.96        0.0
# cluster_p[Uterus, 9]             0.50  0.29    0.06     1.00        0.0
# cluster_p[Uterus, 5]             0.50  0.29    0.06     0.99        0.0
# cluster_p[Uterus, 8]             0.50  0.29    0.01     0.95        0.0
# cluster_p[Uterus, 3]             0.50  0.29    0.03     0.96        0.0
#
#                                  mcse_sd  ess_bulk  ess_tail  r_hat
# basket_p[Biliary Tract]              0.0   32644.0   13318.0    1.0
# basket_p[Bladder/Urinary Tract]      0.0   30858.0   12343.0    1.0
# basket_p[Bone]                       0.0   18038.0   11952.0    1.0
# basket_p[Bowel]                      0.0   25019.0   13066.0    1.0
# basket_p[Breast]                     0.0   23582.0   11550.0    1.0
# ...                                  ...       ...       ...    ...
# cluster_p[Uterus, 7]                 0.0   35651.0   12831.0    1.0
# cluster_p[Uterus, 9]                 0.0   43564.0   11869.0    1.0
# cluster_p[Uterus, 5]                 0.0   42223.0   12845.0    1.0
# cluster_p[Uterus, 8]                 0.0   36186.0   12613.0    1.0
# cluster_p[Uterus, 3]                 0.0   44959.0   12553.0    1.0
#
# [264 rows x 9 columns]

# %%
# az.plot_ess(
#     trace_s, kind="evolution", var_names=['basket_p', 'cluster_p']
# )

# %%
az.plot_trace(trace_s, var_names=['basket_p']);

# %%
az.plot_forest(trace_s, var_names=['basket_p'])
# Out:
# array([<AxesSubplot: title={'center': '94.0% HDI'}>], dtype=object)

# %%
stacked_s = az.extract(trace_s)

# %%
inferred_basket_s = np.mean(stacked_s.basket_p.values, axis=1)
inferred_basket_s.shape
# Out:
# (24,)

# %%
inferred_cluster_s = np.mean(stacked_s.cluster_p.values, axis=2)
inferred_cluster_s.shape
# Out:
# (24, 10)

# %%
inferred_basket_s_tiled = np.tile(inferred_basket_s, (C, 1)).T
inferred_mat_s = inferred_basket_s_tiled * inferred_cluster_s
inferred_mat_s.shape
# Out:
# (24, 10)

# %% [markdown]
# ### Hierarchical model 1

# %% [markdown]
# This hierarchical model suffers from a lot of divergences. See:
# - https://discourse.pymc.io/t/non-centered-parameterization-of-a-beta-distribution/6872/7
# - https://stats.stackexchange.com/questions/67443/does-the-beta-distribution-have-a-conjugate-prior

# %%
model_h1 = get_patient_model_hierarchical(patient_df)

# %%
pm.model_to_graphviz(model_h1)

# %%
with model_h1:
    trace_h1 = pm.sample(n_sample, tune=n_burn_in, idata_kwargs={'log_likelihood': True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [basket_alpha, basket_beta, cluster_alpha, cluster_beta, basket_p, cluster_p]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 07:51&lt;00:00 Sampling 4 chains, 5,827 divergences]
#     </div>
# Sampling 4 chains for 5_000 tune and 5_000 draw iterations (20_000 + 20_000 draws total) took 506 seconds.
# There were 1462 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 1366 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 1300 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 1699 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6544, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
az.summary(trace_h1).round(2)
# Out:
#                       mean    sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# basket_alpha          0.85  0.13    0.61     1.00       0.00      0.0
# basket_beta           0.47  0.21    0.11     0.87       0.01      0.0
# cluster_alpha[4]      0.44  0.23    0.08     0.90       0.01      0.0
# cluster_alpha[0]      0.72  0.20    0.37     1.00       0.00      0.0
# cluster_alpha[2]      0.76  0.18    0.44     1.00       0.00      0.0
# ...                    ...   ...     ...      ...        ...      ...
# cluster_p[Uterus, 7]  0.55  0.36    0.01     1.00       0.00      0.0
# cluster_p[Uterus, 9]  0.58  0.36    0.01     1.00       0.00      0.0
# cluster_p[Uterus, 5]  0.60  0.35    0.02     1.00       0.00      0.0
# cluster_p[Uterus, 8]  0.60  0.35    0.02     1.00       0.00      0.0
# cluster_p[Uterus, 3]  0.57  0.36    0.01     1.00       0.00      0.0
#
#                       ess_bulk  ess_tail  r_hat
# basket_alpha            7054.0    8546.0    1.0
# basket_beta              749.0    1342.0    1.0
# cluster_alpha[4]         894.0     886.0    1.0
# cluster_alpha[0]        5003.0    5027.0    1.0
# cluster_alpha[2]        5135.0    5735.0    1.0
# ...                        ...       ...    ...
# cluster_p[Uterus, 7]    4730.0    3943.0    1.0
# cluster_p[Uterus, 9]    3661.0    2522.0    1.0
# cluster_p[Uterus, 5]    4959.0    3085.0    1.0
# cluster_p[Uterus, 8]    4956.0    3182.0    1.0
# cluster_p[Uterus, 3]    2958.0    1636.0    1.0
#
# [286 rows x 9 columns]

# %%
# az.plot_ess(
#     trace_h1, kind="evolution", var_names=['basket_p', 'cluster_p']
# )

# %%
az.plot_trace(trace_h1, var_names=['basket_p']);

# %%
az.plot_forest(trace_h1, var_names=['basket_p'])
# Out:
# array([<AxesSubplot: title={'center': '94.0% HDI'}>], dtype=object)

# %%
stacked_h1 = az.extract(trace_h1)

# %%
inferred_basket_h1 = np.mean(stacked_h1.basket_p.values, axis=1)
inferred_basket_h1.shape
# Out:
# (24,)

# %%
inferred_cluster_h1 = np.mean(stacked_h1.cluster_p.values, axis=2)
inferred_cluster_h1.shape
# Out:
# (24, 10)

# %%
inferred_basket_h1_tiled = np.tile(inferred_basket_h1, (C, 1)).T
inferred_mat_h1 = inferred_basket_h1_tiled * inferred_cluster_h1
inferred_mat_h1.shape
# Out:
# (24, 10)

# %% [markdown]
# ### Hierarchical model 2

# %% [markdown]
# Another hierarchical model, but modelling the log-odds instead.

# %%
model_h2 = get_patient_model_hierarchical_log_odds(patient_df)

# %%
pm.model_to_graphviz(model_h2)

# %%
# with model_h2:
#     trace_h2 = pm.sample(n_sample, tune=n_burn_in, idata_kwargs={'log_likelihood': True})

# %% [markdown]
# This is the one we actually use after reparameterisation.

# %%
model_h2_nc = get_patient_model_hierarchical_log_odds_nc(patient_df)

# %%
pm.model_to_graphviz(model_h2_nc)

# %%
with model_h2_nc:
    trace_h2 = pm.sample(n_sample, tune=n_burn_in, idata_kwargs={'log_likelihood': True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [z_basket, z_cluster, basket_mu, cluster_mu, basket_sigma, cluster_sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 03:04&lt;00:00 Sampling 4 chains, 1 divergences]
#     </div>
# Sampling 4 chains for 5_000 tune and 5_000 draw iterations (20_000 + 20_000 draws total) took 226 seconds.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.

# %%
az.summary(trace_h2).round(2)
# Out:
#                                  mean    sd  hdi_3%  hdi_97%  mcse_mean  \
# z_basket[Biliary Tract]          0.21  0.97   -1.63     2.04        0.0
# z_basket[Bladder/Urinary Tract]  0.24  0.96   -1.53     2.09        0.0
# z_basket[Bone]                   0.17  0.96   -1.67     1.96        0.0
# z_basket[Bowel]                  0.17  0.96   -1.59     2.00        0.0
# z_basket[Breast]                 0.09  0.95   -1.68     1.92        0.0
# ...                               ...   ...     ...      ...        ...
# cluster_p[Uterus, 7]             0.71  0.23    0.27     1.00        0.0
# cluster_p[Uterus, 9]             0.69  0.23    0.28     1.00        0.0
# cluster_p[Uterus, 5]             0.73  0.21    0.34     1.00        0.0
# cluster_p[Uterus, 8]             0.76  0.19    0.42     1.00        0.0
# cluster_p[Uterus, 3]             0.73  0.22    0.32     1.00        0.0
#
#                                  mcse_sd  ess_bulk  ess_tail  r_hat
# z_basket[Biliary Tract]             0.01   37861.0   14445.0    1.0
# z_basket[Bladder/Urinary Tract]     0.01   33247.0   15509.0    1.0
# z_basket[Bone]                      0.01   32138.0   15597.0    1.0
# z_basket[Bowel]                     0.01   33007.0   15734.0    1.0
# z_basket[Breast]                    0.01   30760.0   14475.0    1.0
# ...                                  ...       ...       ...    ...
# cluster_p[Uterus, 7]                0.00   25592.0   16348.0    1.0
# cluster_p[Uterus, 9]                0.00   23428.0   14912.0    1.0
# cluster_p[Uterus, 5]                0.00   23738.0   15611.0    1.0
# cluster_p[Uterus, 8]                0.00   24428.0   16021.0    1.0
# cluster_p[Uterus, 3]                0.00   24093.0   15964.0    1.0
#
# [596 rows x 9 columns]

# %%
# az.plot_ess(
#     trace_h2, kind="evolution", var_names=['basket_p', 'cluster_p']
# )

# %%
az.plot_trace(trace_h2, var_names=['basket_p']);

# %%
az.plot_forest(trace_h2, var_names=['basket_p'])
# Out:
# array([<AxesSubplot: title={'center': '94.0% HDI'}>], dtype=object)

# %%
stacked_h2 = az.extract(trace_h2)

# %%
inferred_basket_h2 = np.mean(stacked_h2.basket_p.values, axis=1)
inferred_basket_h2.shape
# Out:
# (24,)

# %%
inferred_cluster_h2 = np.mean(stacked_h2.cluster_p.values, axis=2)
inferred_cluster_h2.shape
# Out:
# (24, 10)

# %%
inferred_basket_h2_tiled = np.tile(inferred_basket_h2, (C, 1)).T
inferred_mat_h2 = inferred_basket_h2_tiled * inferred_cluster_h2
inferred_mat_h2.shape
# Out:
# (24, 10)

# %% [markdown]
# ## Compare the matrices

# %%
predicted_basket_s_df = pd.DataFrame({'prob': inferred_basket_s, 'basket': range(len(inferred_basket_s))})
predicted_basket_h1_df = pd.DataFrame({'prob': inferred_basket_h1, 'basket': range(len(inferred_basket_h1))})
predicted_basket_h2_df = pd.DataFrame({'prob': inferred_basket_h2, 'basket': range(len(inferred_basket_h2))})

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5), sharex=True, sharey=True)

sns.barplot(data=predicted_basket_s_df, x='basket', y='prob', ax=ax[0])
ax[0].set_title('Inferred (simple)')

sns.barplot(data=predicted_basket_h1_df, x='basket', y='prob', ax=ax[1])
ax[1].set_title('Inferred (hierarchical)')

sns.barplot(data=predicted_basket_h2_df, x='basket', y='prob', ax=ax[2])
ax[2].set_title('Inferred (hierarchical log-odds)')
# Out:
# Text(0.5, 1.0, 'Inferred (hierarchical log-odds)')

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5), sharex=True, sharey=True)
    
sns.heatmap(inferred_cluster_s, ax=ax[0])
ax[0].set_title('Inferred (simple)')
ax[0].set_xlabel('Clusters')
ax[0].set_ylabel('Baskets')
    
sns.heatmap(inferred_cluster_h1, ax=ax[1])
ax[1].set_title('Inferred (hierarchical)')
ax[1].set_xlabel('Clusters')
ax[1].set_ylabel('Baskets')
    
sns.heatmap(inferred_cluster_h2, ax=ax[2])
ax[2].set_title('Inferred (hierarchical log-odds)')
ax[2].set_xlabel('Clusters')
ax[2].set_ylabel('Baskets')
# Out:
# Text(1321.8954248366013, 0.5, 'Baskets')

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5), sharex=True, sharey=True)
    
sns.heatmap(inferred_mat_s, ax=ax[0])
ax[0].set_title('Inferred (simple)')
ax[0].set_xlabel('Clusters')
ax[0].set_ylabel('Baskets')
    
sns.heatmap(inferred_mat_h1, ax=ax[1])
ax[1].set_title('Inferred (hierarchical)')
ax[1].set_xlabel('Clusters')
ax[1].set_ylabel('Baskets')
    
sns.heatmap(inferred_mat_h2, ax=ax[2])
ax[2].set_title('Inferred (hierarchical log-odds)')
ax[2].set_xlabel('Clusters')
ax[2].set_ylabel('Baskets')
# Out:
# Text(1321.8954248366013, 0.5, 'Baskets')

# %% [markdown]
# ## Model comparison

# %%
# import warnings
# warnings.filterwarnings("ignore", category=UserWarning, module="arviz.stats.stats")

# %%
loo_s = az.loo(trace_s)
loo_s
# Out:
# Computed from 20000 posterior samples and 298 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo  -195.32     6.97
# p_loo       30.76        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      288   96.6%
#  (0.5, 0.7]   (ok)         10    3.4%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%

# %%
loo_h1 = az.loo(trace_h1)
loo_h1
# Out:
# /opt/anaconda3/envs/pyBasket/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# Computed from 20000 posterior samples and 298 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo  -197.23     7.28
# p_loo       39.23        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      257   86.2%
#  (0.5, 0.7]   (ok)         37   12.4%
#    (0.7, 1]   (bad)         4    1.3%
#    (1, Inf)   (very bad)    0    0.0%

# %%
loo_h2 = az.loo(trace_h2)
loo_h2
# Out:
# Computed from 20000 posterior samples and 298 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo  -195.84     6.86
# p_loo       28.02        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      290   97.3%
#  (0.5, 0.7]   (ok)          8    2.7%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%

# %%
ic = 'loo'
df_comp_loo = az.compare({
    's': loo_s, 
    'h1': loo_h1,
    'h2': loo_h2,    
}, ic=ic)
df_comp_loo
# Out:
#     rank    elpd_loo      p_loo  elpd_diff        weight        se       dse  \
# s      0 -195.321799  30.755660   0.000000  5.716186e-01  6.973414  0.000000
# h2     1 -195.841833  28.021381   0.520034  4.283814e-01  6.859092  2.684920
# h1     2 -197.233840  39.226419   1.912040  2.664535e-15  7.281043  2.310431
#
#     warning scale
# s     False   log
# h2    False   log
# h1     True   log

# %%
az.plot_compare(df_comp_loo);

# %% [markdown]
# # Save results

# %% [markdown]
# Save all the results to check in another notebook.

# %%
expr_df_filtered.shape, expr_df_selected.shape, len(class_labels), len(cluster_labels), patient_df.shape
# Out:
# ((298, 19957), (298, 500), 298, 298, (298, 5))

# %%
drug_name, C
# Out:
# ('Erlotinib', 10)

# %%
save_data = {
    'expr_df_filtered': expr_df_filtered,
    'expr_df_selected': expr_df_selected,
    'drug_response': drug_response,
    'class_labels': class_labels,
    'cluster_labels': cluster_labels,
    'patient_df': patient_df,
    'stacked_posterior': stacked_h2,
    'trace': trace_h2,
    'importance_df': importance_df
}
save_obj(save_data, os.path.join('results', 'patient_analysis_%s_cluster_%d.p' % (drug_name, C)))
# Out:
# 2023-03-10 00:36:50.549 | INFO     | pyBasket.common:save_obj:62 - Saving <class 'dict'> to results/patient_analysis_Erlotinib_cluster_10.p

# %%
patient_df.to_csv(os.path.join('results', 'patient_analysis_%s_cluster_%d.csv' % (drug_name, C)))
