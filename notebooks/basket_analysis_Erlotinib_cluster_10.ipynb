# %% [markdown]
# # GDSCv2 Analysis - Erlotinib (10 clusters)
#
# This notebook shows a PyMC model that incorporates basket + clustering

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

sys.path.append('..')
sys.path.append('.')

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import seaborn as sns

# %%
from pyBasket.common import load_obj, save_obj
from pyBasket.model import get_model_simple, get_model_bhm_nc, get_model_logres_nc
from pyBasket.clustering import get_cluster_df_by_basket, plot_PCA
from pyBasket.preprocessing import select_rf, check_rf

# %% [markdown]
# # Load expression data

# %%
data_dir = os.path.abspath(os.path.join('..', 'Data'))
data_dir
# Out:
# '/Users/joewandy/Work/git/pyBasket/Data'

# %% [markdown]
# The data consists of 446 samples x 19957 transcripts

# %%
expr_file = os.path.join(data_dir, 'GDSCv2.exprsALL.tsv')
df = pd.read_csv(expr_file, sep='\t')
expr_df = df.drop(df.index[-25:]).transpose()
expr_df
# Out:
#            ENSG00000000003.15  ENSG00000000005.6  ENSG00000000419.12  \
# TGBC24TKB            3.842223          -5.465508            6.643472
# EGI-1                5.477477          -3.712215            5.685061
# TGBC1TKB             5.247886          -5.464387            6.443945
# ETK-1                5.772839          -5.669225            6.345230
# SW1710               3.891433          -6.720904            6.461246
# ...                       ...                ...                 ...
# ASH-3                3.230687          -9.965784            6.793055
# KMH-2                2.644470          -9.965784            7.369643
# HTC-C3               4.297403          -9.965784            6.790183
# IHH-4                2.770616          -5.795143            5.490973
# HEC-1                4.511196          -4.535588            6.296627
#
#            ENSG00000000457.14  ENSG00000000460.17  ENSG00000000938.13  \
# TGBC24TKB            2.413681            3.523928           -6.722421
# EGI-1                3.274900            3.243179           -4.146015
# TGBC1TKB             2.174270            4.884496           -3.860326
# ETK-1                2.088130            4.272358           -6.904595
# SW1710               2.432792            3.541814           -6.584625
# ...                       ...                 ...                 ...
# ASH-3                2.174138            2.815748           -6.168741
# KMH-2                2.521319            4.211213           -9.965784
# HTC-C3               1.780538            2.229505           -2.115773
# IHH-4                3.801877            4.603189           -2.927377
# HEC-1                2.463557            4.079280           -6.010182
#
#            ENSG00000000971.16  ENSG00000001036.14  ENSG00000001084.13  \
# TGBC24TKB            1.493328            5.312851            7.657224
# EGI-1                4.508079            4.801951            4.677299
# TGBC1TKB            -2.119720            6.585122            7.530231
# ETK-1                2.426256            6.914759            6.597911
# SW1710               4.976817            5.593969            4.455942
# ...                       ...                 ...                 ...
# ASH-3                3.105009            4.966726            4.675848
# KMH-2                1.926462            5.212597            3.104173
# HTC-C3               3.557124            4.339450            4.492282
# IHH-4               -3.172772           -0.264386            4.179838
# HEC-1                0.860272            5.429501            5.651821
#
#            ENSG00000001167.14  ...  ENSG00000288436.1  ENSG00000288460.1  \
# TGBC24TKB            4.241038  ...          -9.965784          -6.590911
# EGI-1                4.812610  ...          -5.393783          -6.552767
# TGBC1TKB             4.834777  ...          -3.459260          -9.965784
# ETK-1                4.163071  ...          -3.497535          -6.780472
# SW1710               5.065822  ...          -2.528606          -5.514698
# ...                       ...  ...                ...                ...
# ASH-3                4.668331  ...          -9.965784          -9.965784
# KMH-2                3.763338  ...          -6.705062          -9.965784
# HTC-C3               4.175475  ...          -9.965784          -6.805531
# IHH-4                4.530007  ...          -2.538738          -5.954484
# HEC-1                3.993226  ...          -3.963675          -6.868090
#
#            ENSG00000288520.1  ENSG00000288529.1  ENSG00000288534.1  \
# TGBC24TKB          -9.965784          -9.965784           3.498175
# EGI-1              -4.030988          -9.965784           2.821231
# TGBC1TKB           -6.932179          -9.965784           2.675651
# ETK-1              -3.047387          -9.965784           3.500665
# SW1710             -4.137394          -9.965784           3.020995
# ...                      ...                ...                ...
# ASH-3              -9.965784          -9.965784           1.998570
# KMH-2              -1.975997          -9.965784           2.052412
# HTC-C3             -9.965784          -9.965784           1.023656
# IHH-4              -9.965784          -9.965784           1.825162
# HEC-1              -4.969760          -9.965784           2.647948
#
#            ENSG00000288547.1  ENSG00000288550.1  ENSG00000288558.1  \
# TGBC24TKB          -9.965784          -0.647309           1.826165
# EGI-1              -9.965784          -1.324475           1.050212
# TGBC1TKB           -3.173723          -2.442109           1.872312
# ETK-1              -9.965784          -1.753472           1.533735
# SW1710             -1.689065          -1.219231           1.743528
# ...                      ...                ...                ...
# ASH-3              -9.965784          -0.486651           0.090239
# KMH-2              -9.965784          -0.561202          -0.021777
# HTC-C3             -9.965784          -1.808425           0.997827
# IHH-4              -9.965784          -2.307655           1.466204
# HEC-1              -9.965784          -1.311239           1.580561
#
#            ENSG00000288564.1  ENSG00000288570.1
# TGBC24TKB          -5.399761          -9.965784
# EGI-1              -3.380326          -9.965784
# TGBC1TKB           -2.986262          -9.965784
# ETK-1              -3.042083          -9.965784
# SW1710             -1.304345          -9.965784
# ...                      ...                ...
# ASH-3              -1.683468          -9.965784
# KMH-2              -2.262192          -9.965784
# HTC-C3             -2.137166          -9.965784
# IHH-4              -2.971226          -9.965784
# HEC-1              -4.063903          -9.965784
#
# [446 rows x 19957 columns]

# %% [markdown]
# Each sample is assigned to one tissue

# %%
tissue_df = df.tail(25).astype(int).transpose()
tissue_df
# Out:
#            CNS/Brain  Bone  Prostate  Esophagus/Stomach  \
# TGBC24TKB          0     0         0                  0
# EGI-1              0     0         0                  0
# TGBC1TKB           0     0         0                  0
# ETK-1              0     0         0                  0
# SW1710             0     0         0                  0
# ...              ...   ...       ...                ...
# ASH-3              0     0         0                  0
# KMH-2              0     0         0                  0
# HTC-C3             0     0         0                  0
# IHH-4              0     0         0                  0
# HEC-1              0     0         0                  0
#
#            Bladder/Urinary Tract  Ovary/Fallopian Tube  Lymphoid  Kidney  \
# TGBC24TKB                      0                     0         0       0
# EGI-1                          0                     0         0       0
# TGBC1TKB                       0                     0         0       0
# ETK-1                          0                     0         0       0
# SW1710                         1                     0         0       0
# ...                          ...                   ...       ...     ...
# ASH-3                          0                     0         0       0
# KMH-2                          0                     0         0       0
# HTC-C3                         0                     0         0       0
# IHH-4                          0                     0         0       0
# HEC-1                          0                     0         0       0
#
#            Thyroid  Soft Tissue  ...  Uterus  Pancreas  Breast  Cervix  Bowel  \
# TGBC24TKB        0            0  ...       0         0       0       0      0
# EGI-1            0            0  ...       0         0       0       0      0
# TGBC1TKB         0            0  ...       0         0       0       0      0
# ETK-1            0            0  ...       0         0       0       0      0
# SW1710           0            0  ...       0         0       0       0      0
# ...            ...          ...  ...     ...       ...     ...     ...    ...
# ASH-3            1            0  ...       0         0       0       0      0
# KMH-2            1            0  ...       0         0       0       0      0
# HTC-C3           1            0  ...       0         0       0       0      0
# IHH-4            1            0  ...       0         0       0       0      0
# HEC-1            0            0  ...       1         0       0       0      0
#
#            Peripheral Nervous System  Liver  Biliary Tract  Other  \
# TGBC24TKB                          0      0              1      0
# EGI-1                              0      0              1      0
# TGBC1TKB                           0      0              1      0
# ETK-1                              0      0              1      0
# SW1710                             0      0              0      0
# ...                              ...    ...            ...    ...
# ASH-3                              0      0              0      0
# KMH-2                              0      0              0      0
# HTC-C3                             0      0              0      0
# IHH-4                              0      0              0      0
# HEC-1                              0      0              0      0
#
#            Ampulla of Vater
# TGBC24TKB                 0
# EGI-1                     0
# TGBC1TKB                  0
# ETK-1                     0
# SW1710                    0
# ...                     ...
# ASH-3                     0
# KMH-2                     0
# HTC-C3                    0
# IHH-4                     0
# HEC-1                     0
#
# [446 rows x 25 columns]

# %%
flat_list = tissue_df.reset_index().melt(id_vars='index', var_name='tissue', value_name='belongs_to_tissue')
flat_list = flat_list[flat_list['belongs_to_tissue'] != 0]

# set the index to the sample name
flat_list = flat_list.set_index('index')

# create the dictionary
sample_dict = flat_list['tissue'].to_dict()

# %%
tissues = np.array([sample_dict[s] for s in expr_df.index.values])
tissues[0:10]
# Out:
# array(['Biliary Tract', 'Biliary Tract', 'Biliary Tract', 'Biliary Tract',
#        'Bladder/Urinary Tract', 'Bladder/Urinary Tract',
#        'Bladder/Urinary Tract', 'Bladder/Urinary Tract',
#        'Bladder/Urinary Tract', 'Bone'], dtype='<U25')

# %% [markdown]
# # Do PCA and colour by basket (tissues)

# %%
_ = plot_PCA(expr_df, n_components=10, hue=tissues)
# Out:
# PCA explained variance [0.12949628 0.22238095 0.28729125 0.32075101 0.34293046 0.36347671
#  0.38132787 0.39535595 0.40877652 0.42098205]

# %% [markdown]
# # Load drug responses data

# %% [markdown]
# Each sample also has its corresponding drug response. There are 11 drugs.
# Not sure why there are 1104 samples?

# %%
response_file = os.path.join(data_dir, 'GDSCv2.aacALL.tsv')
response_df = pd.read_csv(response_file, sep='\t').transpose()
response_df
# Out:
#           Bortezomib  Entinostat  Sirolimus  Docetaxel  Gemcitabine  \
# 143B             NaN         NaN        NaN        NaN          NaN
# 201T             NaN         NaN        NaN        NaN          NaN
# 22Rv1       0.184836    0.142503   0.304184   0.111977     0.596289
# 23132/87    0.228235    0.121580   0.208475   0.232821     0.407328
# 380              NaN         NaN        NaN        NaN          NaN
# ...              ...         ...        ...        ...          ...
# YH-13       0.174638    0.019992   0.157624   0.211467     0.359880
# YKG-1            NaN         NaN        NaN        NaN          NaN
# YMB-1-E          NaN         NaN        NaN        NaN          NaN
# YT          0.230123         NaN   0.212004   0.113564     0.666782
# ZR-75-30    0.029824    0.036509   0.110687   0.061314     0.141155
#
#           Crizotinib  Lapatinib  Vorinostat  Erlotinib  Paclitaxel  Pictilisib
# 143B             NaN        NaN         NaN        NaN         NaN         NaN
# 201T             NaN        NaN         NaN        NaN         NaN         NaN
# 22Rv1       0.077036   0.048663    0.240865   0.069736    0.015539    0.254125
# 23132/87    0.018921   0.172438    0.235145   0.124366    0.025982    0.431203
# 380              NaN        NaN         NaN        NaN         NaN         NaN
# ...              ...        ...         ...        ...         ...         ...
# YH-13       0.008977   0.069979    0.144077   0.108331    0.087400    0.349741
# YKG-1            NaN        NaN         NaN        NaN         NaN         NaN
# YMB-1-E          NaN        NaN         NaN        NaN         NaN         NaN
# YT               NaN   0.084477    0.235547   0.000000    0.000000    0.172903
# ZR-75-30    0.000000   0.402298    0.066816   0.059044    0.000000    0.150910
#
# [1104 rows x 11 columns]

# %%
response_df.loc['TGBC24TKB']
# Out:
# Bortezomib     0.046804
# Entinostat     0.074151
# Sirolimus      0.015096
# Docetaxel      0.229496
# Gemcitabine    0.410541
# Crizotinib     0.000000
# Lapatinib      0.239909
# Vorinostat     0.181613
# Erlotinib      0.128392
# Paclitaxel     0.014104
# Pictilisib     0.387379
# Name: TGBC24TKB, dtype: float64

# %% [markdown]
# ## Collect the samples and responses for the drug

# %%
drug_name = 'Erlotinib'

# %%
samples = tissue_df.index.values
response_dict = response_df[drug_name].to_dict()
responses = np.array([response_dict[s] for s in samples])
len(samples), len(responses), len(tissues)
# Out:
# (446, 446, 446)

# %%
df = pd.DataFrame({
    'tissues': tissues,
    'samples': samples,    
    'responses': responses
})
df
# Out:
#                    tissues    samples  responses
# 0            Biliary Tract  TGBC24TKB   0.128392
# 1            Biliary Tract      EGI-1   0.057719
# 2            Biliary Tract   TGBC1TKB   0.051036
# 3            Biliary Tract      ETK-1   0.096227
# 4    Bladder/Urinary Tract     SW1710   0.071891
# ..                     ...        ...        ...
# 441                Thyroid      ASH-3   0.082204
# 442                Thyroid      KMH-2        NaN
# 443                Thyroid     HTC-C3   0.078680
# 444                Thyroid      IHH-4   0.020141
# 445                 Uterus      HEC-1   0.087076
#
# [446 rows x 3 columns]

# %% [markdown]
# ## Drop all the NaN responses

# %%
df = df.dropna(subset=['responses'])
df
# Out:
#                    tissues    samples  responses
# 0            Biliary Tract  TGBC24TKB   0.128392
# 1            Biliary Tract      EGI-1   0.057719
# 2            Biliary Tract   TGBC1TKB   0.051036
# 3            Biliary Tract      ETK-1   0.096227
# 4    Bladder/Urinary Tract     SW1710   0.071891
# ..                     ...        ...        ...
# 440                Thyroid        WRO   0.018343
# 441                Thyroid      ASH-3   0.082204
# 443                Thyroid     HTC-C3   0.078680
# 444                Thyroid      IHH-4   0.020141
# 445                 Uterus      HEC-1   0.087076
#
# [298 rows x 3 columns]

# %%
df['tissues'].unique()
# Out:
# array(['Biliary Tract', 'Bladder/Urinary Tract', 'Bone', 'Bowel',
#        'Breast', 'Cervix', 'CNS/Brain', 'Esophagus/Stomach',
#        'Head and Neck', 'Kidney', 'Liver', 'Lung', 'Lymphoid', 'Myeloid',
#        'Other', 'Ovary/Fallopian Tube', 'Pancreas',
#        'Peripheral Nervous System', 'Pleura', 'Prostate', 'Skin',
#        'Soft Tissue', 'Thyroid', 'Uterus'], dtype=object)

# %%
df.groupby('tissues').count()
# Out:
#                            samples  responses
# tissues
# Biliary Tract                    4          4
# Bladder/Urinary Tract            5          5
# Bone                            25         25
# Bowel                           28         28
# Breast                          10         10
# CNS/Brain                       14         14
# Cervix                          13         13
# Esophagus/Stomach               19         19
# Head and Neck                   16         16
# Kidney                           5          5
# Liver                            2          2
# Lung                            24         24
# Lymphoid                        53         53
# Myeloid                         12         12
# Other                            3          3
# Ovary/Fallopian Tube            10         10
# Pancreas                         5          5
# Peripheral Nervous System       15         15
# Pleura                          10         10
# Prostate                         2          2
# Skin                             8          8
# Soft Tissue                      7          7
# Thyroid                          7          7
# Uterus                           1          1

# %%
df['responses'].max(), df['responses'].min()
# Out:
# (0.352487709036072, 0.0)

# %%
sns.displot(df['responses'])

# %%
df['responses'].mean(), df['responses'].median()
# Out:
# (0.07533823628570624, 0.06098308922444)

# %% [markdown]
# # Select baskets for analysis

# %% [markdown]
# Select some baskets

# %%
# basket_names = [
#     'Lymphoid',
#     'Bowel',
#     'Bone',
#     'Lung',
#     'Esophagus/Stomach'
# ]

# %% [markdown]
# Use all baskets

# %%
basket_names = df['tissues'].unique()
basket_names
# Out:
# array(['Biliary Tract', 'Bladder/Urinary Tract', 'Bone', 'Bowel',
#        'Breast', 'Cervix', 'CNS/Brain', 'Esophagus/Stomach',
#        'Head and Neck', 'Kidney', 'Liver', 'Lung', 'Lymphoid', 'Myeloid',
#        'Other', 'Ovary/Fallopian Tube', 'Pancreas',
#        'Peripheral Nervous System', 'Pleura', 'Prostate', 'Skin',
#        'Soft Tissue', 'Thyroid', 'Uterus'], dtype=object)

# %%
df_filtered = df[df['tissues'].isin(basket_names)].reset_index(drop=True)
df_filtered
# Out:
#                    tissues    samples  responses
# 0            Biliary Tract  TGBC24TKB   0.128392
# 1            Biliary Tract      EGI-1   0.057719
# 2            Biliary Tract   TGBC1TKB   0.051036
# 3            Biliary Tract      ETK-1   0.096227
# 4    Bladder/Urinary Tract     SW1710   0.071891
# ..                     ...        ...        ...
# 293                Thyroid        WRO   0.018343
# 294                Thyroid      ASH-3   0.082204
# 295                Thyroid     HTC-C3   0.078680
# 296                Thyroid      IHH-4   0.020141
# 297                 Uterus      HEC-1   0.087076
#
# [298 rows x 3 columns]

# %%
sample_list = df_filtered['samples'].tolist()
expr_df_filtered = expr_df[expr_df.index.isin(sample_list)]
expr_df_filtered.shape, expr_df.shape
# Out:
# ((298, 19957), (446, 19957))

# %%
drug_response = df_filtered.set_index('samples').drop(columns=['tissues'])
drug_response
# Out:
#            responses
# samples
# TGBC24TKB   0.128392
# EGI-1       0.057719
# TGBC1TKB    0.051036
# ETK-1       0.096227
# SW1710      0.071891
# ...              ...
# WRO         0.018343
# ASH-3       0.082204
# HTC-C3      0.078680
# IHH-4       0.020141
# HEC-1       0.087076
#
# [298 rows x 1 columns]

# %% [markdown]
# ## Feature selection using random forest

# %%
try: # try to load previously selected features
    fname = os.path.join('results', '%s_expr_df_selected.p' % drug_name)
    expr_df_selected = load_obj(fname)
    
except FileNotFoundError: # if not found, then re-run feature selection
    expr_df_selected = select_rf(expr_df_filtered, drug_response, n_splits=5, percentile_threshold=90, top_genes=500)
    save_obj(expr_df_selected, fname)

# %%
check_rf(expr_df_selected, drug_response, test_size=0.2)
# Out:
# Test set results using selected features:
# MSE: 0.0032920842730129398
# R^2: 0.20947838405718378

# %% [markdown]
# ## Do PCA again on these samples

# %%
pc1, pc2 = plot_PCA(expr_df_selected, n_components=10, hue=df_filtered['tissues'].values)
# Out:
# PCA explained variance [0.2443426  0.31842748 0.37138039 0.41483141 0.43467953 0.45420608
#  0.47068115 0.48621428 0.5008843  0.51525205]

# %%
plt.figure(figsize=(10, 5))
g = sns.scatterplot(x=pc1, y=pc2, hue=df_filtered['responses'].values, palette='Blues')
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1, fontsize=12)

# %% [markdown]
# # Try clustering

# %%
expr_df_filtered.shape
# Out:
# (298, 19957)

# %%
classes = df_filtered.set_index('samples')
classes
# Out:
#                          tissues  responses
# samples
# TGBC24TKB          Biliary Tract   0.128392
# EGI-1              Biliary Tract   0.057719
# TGBC1TKB           Biliary Tract   0.051036
# ETK-1              Biliary Tract   0.096227
# SW1710     Bladder/Urinary Tract   0.071891
# ...                          ...        ...
# WRO                      Thyroid   0.018343
# ASH-3                    Thyroid   0.082204
# HTC-C3                   Thyroid   0.078680
# IHH-4                    Thyroid   0.020141
# HEC-1                     Uterus   0.087076
#
# [298 rows x 2 columns]

# %%
C = 10

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=C, random_state=42)
kmeans.fit(expr_df_selected)

cluster_labels = kmeans.labels_
# df['cluster'] = cluster_labels

cluster_labels
# Out:
# array([4, 4, 0, 4, 2, 0, 2, 0, 0, 1, 6, 6, 2, 6, 6, 6, 6, 6, 2, 6, 6, 1,
#        1, 6, 1, 2, 6, 1, 6, 6, 2, 6, 6, 2, 4, 7, 4, 7, 4, 4, 4, 4, 0, 4,
#        4, 4, 4, 4, 1, 4, 4, 4, 2, 9, 4, 4, 4, 4, 4, 4, 4, 4, 7, 7, 7, 7,
#        7, 7, 7, 7, 0, 7, 4, 0, 0, 0, 9, 0, 2, 7, 0, 0, 7, 1, 0, 2, 1, 2,
#        6, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 4, 4, 0, 0, 7, 4, 4, 0, 4, 4,
#        4, 0, 0, 4, 0, 1, 4, 4, 0, 2, 0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 1, 0,
#        0, 2, 2, 2, 2, 2, 2, 1, 1, 1, 5, 0, 5, 4, 9, 4, 9, 9, 9, 1, 9, 4,
#        0, 9, 4, 1, 9, 9, 9, 7, 5, 9, 9, 8, 8, 8, 3, 8, 3, 3, 3, 3, 8, 8,
#        8, 3, 8, 3, 8, 8, 8, 8, 8, 8, 3, 8, 3, 8, 3, 8, 3, 3, 8, 3, 8, 8,
#        3, 3, 3, 8, 3, 3, 3, 8, 8, 8, 8, 3, 3, 3, 1, 8, 3, 3, 3, 3, 8, 3,
#        8, 8, 8, 8, 3, 8, 8, 3, 8, 8, 2, 4, 3, 4, 4, 2, 2, 4, 2, 1, 4, 2,
#        0, 7, 2, 4, 2, 0, 5, 5, 5, 5, 5, 5, 5, 5, 1, 5, 5, 5, 1, 5, 5, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 7, 2, 1, 1, 1, 1, 1, 1, 1, 2, 2, 2,
#        5, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2], dtype=int32)

# %%
_ = plot_PCA(expr_df_selected, n_components=10, hue=cluster_labels)
# Out:
# PCA explained variance [0.2443426  0.31842748 0.37138039 0.41483141 0.43467953 0.45420608
#  0.47068115 0.48621428 0.5008843  0.51525205]

# %% [markdown]
# # Run basket trial analysis

# %%
basket_names
# Out:
# array(['Biliary Tract', 'Bladder/Urinary Tract', 'Bone', 'Bowel',
#        'Breast', 'Cervix', 'CNS/Brain', 'Esophagus/Stomach',
#        'Head and Neck', 'Kidney', 'Liver', 'Lung', 'Lymphoid', 'Myeloid',
#        'Other', 'Ovary/Fallopian Tube', 'Pancreas',
#        'Peripheral Nervous System', 'Pleura', 'Prostate', 'Skin',
#        'Soft Tissue', 'Thyroid', 'Uterus'], dtype=object)

# %%
K = len(basket_names)
K, C
# Out:
# (24, 10)

# %% [markdown]
# Create clustering dataframe

# %%
class_labels = classes.tissues.values
len(class_labels), len(cluster_labels)
# Out:
# (298, 298)

# %%
cluster_df = get_cluster_df_by_basket(class_labels, cluster_labels)
cluster_df
# Out:
#                                sk_0      sk_1      sk_2      sk_3      sk_4  \
# Biliary Tract              0.250000  0.000000  0.000000  0.000000  0.750000
# Bladder/Urinary Tract      0.600000  0.000000  0.400000  0.000000  0.000000
# Bone                       0.000000  0.200000  0.200000  0.000000  0.000000
# Bowel                      0.035714  0.035714  0.035714  0.000000  0.785714
# Breast                     0.100000  0.000000  0.000000  0.000000  0.000000
# CNS/Brain                  0.000000  0.142857  0.785714  0.000000  0.000000
# Cervix                     0.538462  0.076923  0.076923  0.000000  0.076923
# Esophagus/Stomach          0.315789  0.105263  0.000000  0.000000  0.526316
# Head and Neck              0.750000  0.062500  0.187500  0.000000  0.000000
# Kidney                     0.000000  0.000000  1.000000  0.000000  0.000000
# Liver                      0.000000  1.000000  0.000000  0.000000  0.000000
# Lung                       0.083333  0.125000  0.000000  0.000000  0.166667
# Lymphoid                   0.000000  0.018868  0.000000  0.490566  0.000000
# Myeloid                    0.000000  0.000000  0.000000  0.250000  0.000000
# Other                      0.000000  0.000000  0.333333  0.333333  0.333333
# Ovary/Fallopian Tube       0.100000  0.100000  0.400000  0.000000  0.400000
# Pancreas                   0.200000  0.000000  0.400000  0.000000  0.200000
# Peripheral Nervous System  0.000000  0.133333  0.000000  0.000000  0.000000
# Pleura                     0.000000  0.000000  1.000000  0.000000  0.000000
# Prostate                   0.500000  0.000000  0.000000  0.000000  0.000000
# Skin                       0.000000  0.875000  0.125000  0.000000  0.000000
# Soft Tissue                0.000000  0.000000  0.857143  0.000000  0.000000
# Thyroid                    0.000000  0.000000  0.857143  0.000000  0.142857
# Uterus                     0.000000  0.000000  1.000000  0.000000  0.000000
#
#                                sk_5      sk_6      sk_7      sk_8      sk_9
# Biliary Tract              0.000000  0.000000  0.000000  0.000000  0.000000
# Bladder/Urinary Tract      0.000000  0.000000  0.000000  0.000000  0.000000
# Bone                       0.000000  0.600000  0.000000  0.000000  0.000000
# Bowel                      0.000000  0.000000  0.071429  0.000000  0.035714
# Breast                     0.000000  0.000000  0.900000  0.000000  0.000000
# CNS/Brain                  0.000000  0.071429  0.000000  0.000000  0.000000
# Cervix                     0.000000  0.000000  0.153846  0.000000  0.076923
# Esophagus/Stomach          0.000000  0.000000  0.052632  0.000000  0.000000
# Head and Neck              0.000000  0.000000  0.000000  0.000000  0.000000
# Kidney                     0.000000  0.000000  0.000000  0.000000  0.000000
# Liver                      0.000000  0.000000  0.000000  0.000000  0.000000
# Lung                       0.125000  0.000000  0.041667  0.000000  0.458333
# Lymphoid                   0.000000  0.000000  0.000000  0.490566  0.000000
# Myeloid                    0.000000  0.000000  0.000000  0.750000  0.000000
# Other                      0.000000  0.000000  0.000000  0.000000  0.000000
# Ovary/Fallopian Tube       0.000000  0.000000  0.000000  0.000000  0.000000
# Pancreas                   0.000000  0.000000  0.200000  0.000000  0.000000
# Peripheral Nervous System  0.866667  0.000000  0.000000  0.000000  0.000000
# Pleura                     0.000000  0.000000  0.000000  0.000000  0.000000
# Prostate                   0.000000  0.000000  0.500000  0.000000  0.000000
# Skin                       0.000000  0.000000  0.000000  0.000000  0.000000
# Soft Tissue                0.142857  0.000000  0.000000  0.000000  0.000000
# Thyroid                    0.000000  0.000000  0.000000  0.000000  0.000000
# Uterus                     0.000000  0.000000  0.000000  0.000000  0.000000

# %%
sns.heatmap(cluster_df, cmap='jet')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Add the counts of responsive patients for each basket

# %%
n_trial_df = df_filtered.groupby('tissues').count().drop(columns=['responses'])
n_trial_df.rename(columns={'samples': 'n_trial'}, inplace=True)

# %%
aac_thresh = df['responses'].median()

n_success_df = df_filtered[df_filtered['responses'] < aac_thresh].groupby('tissues').count().drop(columns=['responses'])
n_success_df.rename(columns={'samples': 'n_success'}, inplace=True)

# %%
data_df = pd.concat([cluster_df, n_success_df, n_trial_df], axis=1)
data_df
# Out:
#                                sk_0      sk_1      sk_2      sk_3      sk_4  \
# Biliary Tract              0.250000  0.000000  0.000000  0.000000  0.750000
# Bladder/Urinary Tract      0.600000  0.000000  0.400000  0.000000  0.000000
# Bone                       0.000000  0.200000  0.200000  0.000000  0.000000
# Bowel                      0.035714  0.035714  0.035714  0.000000  0.785714
# Breast                     0.100000  0.000000  0.000000  0.000000  0.000000
# CNS/Brain                  0.000000  0.142857  0.785714  0.000000  0.000000
# Cervix                     0.538462  0.076923  0.076923  0.000000  0.076923
# Esophagus/Stomach          0.315789  0.105263  0.000000  0.000000  0.526316
# Head and Neck              0.750000  0.062500  0.187500  0.000000  0.000000
# Kidney                     0.000000  0.000000  1.000000  0.000000  0.000000
# Liver                      0.000000  1.000000  0.000000  0.000000  0.000000
# Lung                       0.083333  0.125000  0.000000  0.000000  0.166667
# Lymphoid                   0.000000  0.018868  0.000000  0.490566  0.000000
# Myeloid                    0.000000  0.000000  0.000000  0.250000  0.000000
# Other                      0.000000  0.000000  0.333333  0.333333  0.333333
# Ovary/Fallopian Tube       0.100000  0.100000  0.400000  0.000000  0.400000
# Pancreas                   0.200000  0.000000  0.400000  0.000000  0.200000
# Peripheral Nervous System  0.000000  0.133333  0.000000  0.000000  0.000000
# Pleura                     0.000000  0.000000  1.000000  0.000000  0.000000
# Prostate                   0.500000  0.000000  0.000000  0.000000  0.000000
# Skin                       0.000000  0.875000  0.125000  0.000000  0.000000
# Soft Tissue                0.000000  0.000000  0.857143  0.000000  0.000000
# Thyroid                    0.000000  0.000000  0.857143  0.000000  0.142857
# Uterus                     0.000000  0.000000  1.000000  0.000000  0.000000
#
#                                sk_5      sk_6      sk_7      sk_8      sk_9  \
# Biliary Tract              0.000000  0.000000  0.000000  0.000000  0.000000
# Bladder/Urinary Tract      0.000000  0.000000  0.000000  0.000000  0.000000
# Bone                       0.000000  0.600000  0.000000  0.000000  0.000000
# Bowel                      0.000000  0.000000  0.071429  0.000000  0.035714
# Breast                     0.000000  0.000000  0.900000  0.000000  0.000000
# CNS/Brain                  0.000000  0.071429  0.000000  0.000000  0.000000
# Cervix                     0.000000  0.000000  0.153846  0.000000  0.076923
# Esophagus/Stomach          0.000000  0.000000  0.052632  0.000000  0.000000
# Head and Neck              0.000000  0.000000  0.000000  0.000000  0.000000
# Kidney                     0.000000  0.000000  0.000000  0.000000  0.000000
# Liver                      0.000000  0.000000  0.000000  0.000000  0.000000
# Lung                       0.125000  0.000000  0.041667  0.000000  0.458333
# Lymphoid                   0.000000  0.000000  0.000000  0.490566  0.000000
# Myeloid                    0.000000  0.000000  0.000000  0.750000  0.000000
# Other                      0.000000  0.000000  0.000000  0.000000  0.000000
# Ovary/Fallopian Tube       0.000000  0.000000  0.000000  0.000000  0.000000
# Pancreas                   0.000000  0.000000  0.200000  0.000000  0.000000
# Peripheral Nervous System  0.866667  0.000000  0.000000  0.000000  0.000000
# Pleura                     0.000000  0.000000  0.000000  0.000000  0.000000
# Prostate                   0.000000  0.000000  0.500000  0.000000  0.000000
# Skin                       0.000000  0.000000  0.000000  0.000000  0.000000
# Soft Tissue                0.142857  0.000000  0.000000  0.000000  0.000000
# Thyroid                    0.000000  0.000000  0.000000  0.000000  0.000000
# Uterus                     0.000000  0.000000  0.000000  0.000000  0.000000
#
#                            n_success  n_trial
# Biliary Tract                    2.0        4
# Bladder/Urinary Tract            3.0        5
# Bone                            13.0       25
# Bowel                           11.0       28
# Breast                           4.0       10
# CNS/Brain                        9.0       14
# Cervix                           1.0       13
# Esophagus/Stomach                7.0       19
# Head and Neck                    NaN       16
# Kidney                           1.0        5
# Liver                            1.0        2
# Lung                            15.0       24
# Lymphoid                        41.0       53
# Myeloid                          9.0       12
# Other                            1.0        3
# Ovary/Fallopian Tube             4.0       10
# Pancreas                         2.0        5
# Peripheral Nervous System        7.0       15
# Pleura                           6.0       10
# Prostate                         1.0        2
# Skin                             3.0        8
# Soft Tissue                      4.0        7
# Thyroid                          4.0        7
# Uterus                           NaN        1

# %%
data_df = data_df.fillna(0)

# %%
n_burn_in = int(1E3)
n_sample = int(1E3)
target_accept = 0.99

# %% [markdown]
# ## Run simple model

# %%
model_simple = get_model_simple(data_df)
pm.model_to_graphviz(model_simple)

# %%
with model_simple:
    trace_simple = pm.sample(n_sample, tune=n_burn_in, idata_kwargs={'log_likelihood': True}, target_accept=target_accept)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta, theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:09&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 30 seconds.

# %%
az.plot_trace(trace_simple, var_names=['theta']);

# %%
stacked_simple = az.extract(trace_simple)

# %%
az.plot_forest(trace_simple, var_names='theta')

predicted = np.mean(stacked_simple.theta.values, axis=1)
predicted
# Out:
# array([0.47434857, 0.51660799, 0.50541293, 0.40796445, 0.42685378,
#        0.57928794, 0.21989556, 0.39672779, 0.15054565, 0.35651656,
#        0.46657577, 0.5845506 , 0.73283546, 0.63575045, 0.42452426,
#        0.42348511, 0.43484503, 0.46302798, 0.53867545, 0.46309078,
#        0.41576754, 0.51539115, 0.51269072, 0.40615257])

# %% [markdown]
# ## Run BHM

# %%
model_bhm_nc = get_model_bhm_nc(data_df)
pm.model_to_graphviz(model_bhm_nc)

# %%
with model_bhm_nc:
    trace_bhm_nc = pm.sample(n_sample, tune=n_burn_in, idata_kwargs={'log_likelihood': True}, target_accept=target_accept)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [z_alpha, mu_alpha, sigma_alpha]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:08&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 29 seconds.

# %%
az.plot_trace(trace_bhm_nc, var_names=['theta']);

# %%
stacked_bhm_nc = az.extract(trace_bhm_nc)

# %%
az.plot_forest(trace_bhm_nc, var_names='alpha')

predicted = np.mean(stacked_bhm_nc.alpha.values, axis=1)
predicted
# Out:
# array([-0.11122104,  0.0597355 ,  0.0257262 , -0.3948628 , -0.32613665,
#         0.33346973, -1.32347873, -0.45520484, -1.75505295, -0.65539216,
#        -0.14293524,  0.36319978,  1.01583195,  0.59080497, -0.3542044 ,
#        -0.31407988, -0.2868469 , -0.16032516,  0.16286175, -0.14785633,
#        -0.37621671,  0.04859715,  0.06246723, -0.46095252])

# %%
az.plot_forest(trace_bhm_nc, var_names='theta')

predicted = np.mean(stacked_bhm_nc.theta.values, axis=1)
predicted
# Out:
# array([0.47461879, 0.51311481, 0.50620521, 0.40521542, 0.42409727,
#        0.57840253, 0.22660753, 0.39227261, 0.1669965 , 0.35548341,
#        0.46874226, 0.58684008, 0.730027  , 0.63529641, 0.42137223,
#        0.42675741, 0.43486778, 0.46178144, 0.53810698, 0.46663248,
#        0.41289686, 0.51113668, 0.5142851 , 0.4018736 ])

# %% [markdown]
# ## Run logistic regression

# %%
model_logres_nc = get_model_logres_nc(data_df)
pm.model_to_graphviz(model_logres_nc)

# %%
with model_logres_nc:
    trace_logres_nc = pm.sample(n_sample, tune=n_burn_in, idata_kwargs={'log_likelihood': True}, target_accept=target_accept)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [z_alpha, z_beta, mu_alpha, sigma_alpha, sigma_beta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:33&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 60 seconds.

# %%
az.plot_trace(trace_logres_nc, var_names=['alpha', 'beta', 'theta']);

# %%
stacked_logres_nc = az.extract(trace_logres_nc)

# %%
az.plot_forest(trace_logres_nc, var_names='alpha')

predicted = np.mean(stacked_logres_nc.alpha.values, axis=1)
predicted
# Out:
# array([ 0.15877625,  0.31513996,  0.08227622, -0.03966434,  0.05125595,
#         0.23238491, -0.12650686,  0.15312246, -0.20059312, -0.11170798,
#         0.10364024,  0.21796513,  0.19815289,  0.10443685, -0.00427939,
#         0.04275168,  0.09089666,  0.03748468,  0.15508344,  0.14478935,
#         0.01645718,  0.12162021,  0.12539561, -0.00987584])

# %%
az.plot_forest(trace_logres_nc, var_names='beta')

predicted = np.mean(stacked_logres_nc.beta.values, axis=1)
predicted
# Out:
# array([-2.5383086 , -0.31544315,  0.0181881 ,  0.71728205, -0.18084947,
#        -0.06431805,  0.11955936, -0.14030933,  1.20557054,  0.84788178])

# %%
az.plot_forest(trace_logres_nc, var_names='theta')

predicted = np.mean(stacked_logres_nc.theta.values, axis=1)
predicted
# Out:
# array([0.35837051, 0.24736556, 0.52288681, 0.43654129, 0.42400681,
#        0.55046977, 0.19524105, 0.31784266, 0.1215078 , 0.479776  ,
#        0.453566  , 0.57432302, 0.75274257, 0.75249095, 0.54299424,
#        0.4259788 , 0.38744497, 0.48591909, 0.54143419, 0.24669075,
#        0.44078298, 0.53063542, 0.52767543, 0.50351821])

# %% [markdown]
# # Check model fit

# %%
loo_simple = az.loo(trace_simple)
loo_simple
# Out:
# /opt/anaconda3/envs/pyBasket/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# Computed from 4000 posterior samples and 24 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo   -49.60     4.77
# p_loo       12.19        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)        7   29.2%
#  (0.5, 0.7]   (ok)          7   29.2%
#    (0.7, 1]   (bad)         9   37.5%
#    (1, Inf)   (very bad)    1    4.2%

# %%
loo_bhm_nc = az.loo(trace_bhm_nc)
loo_bhm_nc
# Out:
# /opt/anaconda3/envs/pyBasket/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# Computed from 4000 posterior samples and 24 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo   -49.90     5.09
# p_loo       12.22        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)        7   29.2%
#  (0.5, 0.7]   (ok)         11   45.8%
#    (0.7, 1]   (bad)         4   16.7%
#    (1, Inf)   (very bad)    2    8.3%

# %%
loo_logres_nc = az.loo(trace_logres_nc)
loo_logres_nc
# Out:
# /opt/anaconda3/envs/pyBasket/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# Computed from 4000 posterior samples and 24 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo   -47.69     3.64
# p_loo        9.03        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)       11   45.8%
#  (0.5, 0.7]   (ok)          6   25.0%
#    (0.7, 1]   (bad)         7   29.2%
#    (1, Inf)   (very bad)    0    0.0%

# %%
ic = 'loo'
df_comp_loo = az.compare({
    'simple': trace_simple, 
    'bhm': trace_bhm_nc,
    'logres': loo_logres_nc,
}, ic=ic)
df_comp_loo
# Out:
# /opt/anaconda3/envs/pyBasket/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /opt/anaconda3/envs/pyBasket/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
#         rank   elpd_loo      p_loo  elpd_diff    weight        se       dse  \
# logres     0 -47.692269   9.026948   0.000000  0.730654  3.637327  0.000000
# simple     1 -49.598697  12.185057   1.906428  0.000000  4.774233  3.096652
# bhm        2 -49.898928  12.216428   2.206658  0.269346  5.085274  3.484013
#
#         warning scale
# logres     True   log
# simple     True   log
# bhm        True   log

# %%
az.plot_compare(df_comp_loo);

# %% [markdown]
# # Any interesting data to look at?

# %% [markdown]
# ## Which baskets have the highest / lowest response rates?

# %%
theta_pred = np.mean(stacked_logres_nc.theta.values, axis=1)
idx = np.argsort(theta_pred)

sorted_theta_pred = theta_pred[idx]
sorted_basket_names = basket_names[idx]
sorted_theta_pred, sorted_basket_names
# Out:
# (array([0.1215078 , 0.19524105, 0.24669075, 0.24736556, 0.31784266,
#         0.35837051, 0.38744497, 0.42400681, 0.4259788 , 0.43654129,
#         0.44078298, 0.453566  , 0.479776  , 0.48591909, 0.50351821,
#         0.52288681, 0.52767543, 0.53063542, 0.54143419, 0.54299424,
#         0.55046977, 0.57432302, 0.75249095, 0.75274257]),
#  array(['Head and Neck', 'CNS/Brain', 'Prostate', 'Bladder/Urinary Tract',
#         'Esophagus/Stomach', 'Biliary Tract', 'Pancreas', 'Breast',
#         'Ovary/Fallopian Tube', 'Bowel', 'Skin', 'Liver', 'Kidney',
#         'Peripheral Nervous System', 'Uterus', 'Bone', 'Thyroid',
#         'Soft Tissue', 'Pleura', 'Other', 'Cervix', 'Lung', 'Myeloid',
#         'Lymphoid'], dtype=object))

# %% [markdown]
# ## Pick top few baskets having the highest and lowest response rates

# %%
pick = 5
selected_names = list(sorted_basket_names[0:pick]) + list(sorted_basket_names[-pick:])
selected_theta = list(sorted_theta_pred[0:pick]) + list(sorted_theta_pred[-pick:])
selected_names, selected_theta
selected_df = pd.DataFrame({
    'tissue': selected_names,
    'theta': selected_theta
}).set_index('tissue')
selected_df
# Out:
#                           theta
# tissue
# Head and Neck          0.121508
# CNS/Brain              0.195241
# Prostate               0.246691
# Bladder/Urinary Tract  0.247366
# Esophagus/Stomach      0.317843
# Other                  0.542994
# Cervix                 0.550470
# Lung                   0.574323
# Myeloid                0.752491
# Lymphoid               0.752743

# %% [markdown]
# ## Create a dataframe for all the relevant info

# %%
selected_df = selected_df.join(data_df, how='left')
selected_df
# Out:
#                           theta      sk_0      sk_1      sk_2      sk_3  \
# tissue
# Head and Neck          0.121508  0.750000  0.062500  0.187500  0.000000
# CNS/Brain              0.195241  0.000000  0.142857  0.785714  0.000000
# Prostate               0.246691  0.500000  0.000000  0.000000  0.000000
# Bladder/Urinary Tract  0.247366  0.600000  0.000000  0.400000  0.000000
# Esophagus/Stomach      0.317843  0.315789  0.105263  0.000000  0.000000
# Other                  0.542994  0.000000  0.000000  0.333333  0.333333
# Cervix                 0.550470  0.538462  0.076923  0.076923  0.000000
# Lung                   0.574323  0.083333  0.125000  0.000000  0.000000
# Myeloid                0.752491  0.000000  0.000000  0.000000  0.250000
# Lymphoid               0.752743  0.000000  0.018868  0.000000  0.490566
#
#                            sk_4   sk_5      sk_6      sk_7      sk_8  \
# tissue
# Head and Neck          0.000000  0.000  0.000000  0.000000  0.000000
# CNS/Brain              0.000000  0.000  0.071429  0.000000  0.000000
# Prostate               0.000000  0.000  0.000000  0.500000  0.000000
# Bladder/Urinary Tract  0.000000  0.000  0.000000  0.000000  0.000000
# Esophagus/Stomach      0.526316  0.000  0.000000  0.052632  0.000000
# Other                  0.333333  0.000  0.000000  0.000000  0.000000
# Cervix                 0.076923  0.000  0.000000  0.153846  0.000000
# Lung                   0.166667  0.125  0.000000  0.041667  0.000000
# Myeloid                0.000000  0.000  0.000000  0.000000  0.750000
# Lymphoid               0.000000  0.000  0.000000  0.000000  0.490566
#
#                            sk_9  n_success  n_trial
# tissue
# Head and Neck          0.000000        0.0       16
# CNS/Brain              0.000000        9.0       14
# Prostate               0.000000        1.0        2
# Bladder/Urinary Tract  0.000000        3.0        5
# Esophagus/Stomach      0.000000        7.0       19
# Other                  0.000000        1.0        3
# Cervix                 0.076923        1.0       13
# Lung                   0.458333       15.0       24
# Myeloid                0.000000        9.0       12
# Lymphoid               0.000000       41.0       53

# %% [markdown]
# ## Plot their partitions again

# %%
sns.heatmap(selected_df.iloc[:, 1:11], cmap='jet')
# Out:
# <AxesSubplot: ylabel='tissue'>

# %% [markdown]
# ## Plot inferred cluster coefficients

# %%
beta_pred = np.mean(stacked_logres_nc.beta.values, axis=1)
plot_df = pd.DataFrame({
    'cluster': [i for i in range(C)],
    'weight': beta_pred
    
})
sns.barplot(plot_df, x='cluster', y='weight')
# Out:
# <AxesSubplot: xlabel='cluster', ylabel='weight'>

# %% [markdown]
# ## Check Cluster 0

# %%
query_cluster_idx = 0
query_cluster = 'sk_%d' % query_cluster_idx
query_tissues = data_df[(data_df[query_cluster] > 0)].index.values
query_cluster, query_tissues
# Out:
# ('sk_0',
#  array(['Biliary Tract', 'Bladder/Urinary Tract', 'Bowel', 'Breast',
#         'Cervix', 'Esophagus/Stomach', 'Head and Neck', 'Lung',
#         'Ovary/Fallopian Tube', 'Pancreas', 'Prostate'], dtype=object))

# %%
expr_df_filtered.shape, df_filtered.shape, class_labels.shape, cluster_labels.shape
# Out:
# ((298, 19957), (298, 3), (298,), (298,))

# %%
query_idx = np.isin(class_labels, query_tissues)

query_expr = expr_df_filtered[query_idx]
query_df = df_filtered[query_idx]
query_class_labels = class_labels[query_idx]
query_cluster_labels = cluster_labels[query_idx]

query_df.shape, query_expr.shape, query_class_labels.shape, query_cluster_labels.shape
# Out:
# ((136, 3), (136, 19957), (136,), (136,))

# %%
pc1, pc2 = plot_PCA(query_expr, n_components=10, hue=query_cluster_labels, style=query_class_labels)
# Out:
# PCA explained variance [0.11057208 0.19583657 0.25308622 0.28572071 0.31225778 0.33539262
#  0.35446073 0.37176555 0.3876363  0.40262102]

# %%
plt.figure(figsize=(10, 5))
g = sns.scatterplot(x=pc1, y=pc2, hue=query_df['responses'].values, style=query_class_labels, palette='Blues')
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1, fontsize=12)

# %% [markdown]
# ## Check Cluster 8

# %%
query_cluster_idx = 8
query_cluster = 'sk_%d' % query_cluster_idx
query_tissues = data_df[(data_df[query_cluster] > 0)].index.values
query_cluster, query_tissues
# Out:
# ('sk_8', array(['Lymphoid', 'Myeloid'], dtype=object))

# %%
expr_df_filtered.shape, df_filtered.shape, class_labels.shape, cluster_labels.shape
# Out:
# ((298, 19957), (298, 3), (298,), (298,))

# %%
query_idx = np.isin(class_labels, query_tissues)

query_expr = expr_df_filtered[query_idx]
query_df = df_filtered[query_idx]
query_class_labels = class_labels[query_idx]
query_cluster_labels = cluster_labels[query_idx]

query_df.shape, query_expr.shape, query_class_labels.shape, query_cluster_labels.shape
# Out:
# ((65, 3), (65, 19957), (65,), (65,))

# %%
pc1, pc2 = plot_PCA(query_expr, n_components=10, hue=query_cluster_labels, style=query_class_labels)
# Out:
# PCA explained variance [0.11027159 0.20864415 0.2652688  0.31155567 0.35317718 0.38726136
#  0.41811153 0.44394544 0.46660537 0.48670502]

# %%
plt.figure(figsize=(10, 5))
g = sns.scatterplot(x=pc1, y=pc2, hue=query_df['responses'].values, style=query_class_labels, palette='Blues')
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1, fontsize=12)
